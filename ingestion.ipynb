# %% [markdown]
# #### Instructions:
# 1. Have the .env file updated in your current directory
# 2. Change your email in the user_agent
# 3. Change the subset to your own subset
# 4. Run the code

# %%
import requests
import pandas as pd
import sqlite3
import numpy as np
from io import StringIO, BytesIO
import glob
import os
import boto3
import json

import os
from dotenv import load_dotenv

from datetime import date

# %% [markdown]
# #### change your email

# %%
user_agent = "name.surname@bts.tech" # Change your email

# %% [markdown]
# ### Loading the aws credentials as env variables

# %%
today_date = str(date.today())

# loading variables from .env file
load_dotenv() 

# accessing and printing value
aws_access_key_id = os.getenv("aws_access_key_id")
aws_secret_access_key = os.getenv("aws_secret_access_key")
aws_session_token = os.getenv("aws_session_token")
s3_bucket = "financy"

# %% [markdown]
# #### Getting all the tickers available in the EDGAR Database

# %%
headers = {'User-Agent': user_agent}

companyTickers = requests.get("https://www.sec.gov/files/company_tickers.json", headers = headers)
companyData = pd.DataFrame.from_dict(companyTickers.json(), orient = 'index')
# We need to add zeros because some CIKs differ in digits and the API needs 10 digit CIK. 
companyData['cik_str'] = companyData['cik_str'].astype(str).str.zfill(10)

# %% [markdown]
# #### Diving computational power among the group
# Each member will run the code

# %%
# Dividing the dataset in three parts. 
sub_Jose=companyData[:2572]
sub_Karen=companyData[2572:5144]
sub_Felix=companyData[5144:7716]
sub_Arturo=companyData[7716:]

# %% [markdown]
# #### From EDGAR Database to private s3_bucket
# Function to pull company data from the API and upload it directly to s3

# %%
def tickerJson_uploader(tickers, companyData, s3_bucket):
    s3 = boto3.client("s3",
                      aws_access_key_id=aws_access_key_id,
                      aws_secret_access_key=aws_secret_access_key,
                      aws_session_token=aws_session_token)

    counter_total_tries = 0
    counter_total_uploaded = 0
    
    for ticker in tickers:
        try:
            # Retrieve the CIK value corresponding to the ticker
            try:
                cik_val = str(companyData.loc[companyData['ticker'] == ticker, 'cik_str'].values[0])
            except IndexError:
                print(f"{ticker} not found in Company Data")
                continue

            # Fetch financial data for the company from EDGAR
            print(f"Successful CIK extraction for {ticker}")
            response = requests.get(f'https://data.sec.gov/api/xbrl/companyfacts/CIK{cik_val}.json', headers = headers)
            
            # Check if the request was successful
            response.raise_for_status()
            
            # Convert JSON response to dictionary
            companyFacts = response.json()
            json_str=json.dumps(companyFacts)
            json_bytes=json_str.encode("utf-8")
            print("Successfully converted to json bytes")
            
            # Preparing the JSON for s3 upload
            json_buffer=BytesIO()
            json_buffer.write(json_bytes)
            json_buffer.seek(0)
            
            # Defining the s3 bucket location.
            s3_file_path = f"egdar_data/raw/{today_date}/{ticker}.json"
            
            #Upload to S3 bucket
            s3.upload_fileobj(json_buffer, s3_bucket, s3_file_path)
            print(f"Data for {ticker} uploaded to S3: {s3_file_path}")
            counter_total_uploaded += 1
            print("total companies uploaded:", counter_total_uploaded)
                
        except KeyError:
            print(f"{ticker} not found in Company Data")
        except requests.HTTPError as e:
            print(f"HTTP error for {ticker}: {e}")
        except requests.RequestException as e:
            print(f"Request exception for {ticker}: {e}")

        counter_total_tries +=1
        print("total tries:", counter_total_tries)
        
    print("total companies uploaded:", counter_total_uploaded)

# %% [markdown]
# #### change your sub_section of data!
# sub_section options:
# sub_Jose;
# sub_Karen;
# sub_Felix;
# sub_Arturo

# %%
sub_section = sub_Karen # HERE!

# %%
sub_section_1 = sub_section[:500]
sub_section_2 = sub_section[500:1000]
sub_section_3 = sub_section[1000:1500]
sub_section_4 = sub_section[1500:2000]
sub_section_5 = sub_section[2000:]

# %% [markdown]
# #### Run the code

# %%
tickers = list(sub_section_1['ticker'])

# Run the Ingestion Function
tickerJson_uploader(tickers, companyData, s3_bucket)

# %%
tickers = list(sub_section_2['ticker'])

# Run the Ingestion Function
tickerJson_uploader(tickers, companyData, s3_bucket)

# %%
tickers = list(sub_section_3['ticker'])

# Run the Ingestion Function
tickerJson_uploader(tickers, companyData, s3_bucket)

# %%
tickers = list(sub_section_4['ticker'])

# Run the Ingestion Function
tickerJson_uploader(tickers, companyData, s3_bucket)
# Out:
# Successful CIK extraction for MHI
# HTTP error for MHI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001223026.json
# total tries: 1
# Successful CIK extraction for LMDXF
# Successfully converted to json bytes
# Data for LMDXF uploaded to S3: egdar_data/raw/2024-06-02/LMDXF.json
# total companies uploaded: 1
# total tries: 2
# Successful CIK extraction for SEDA
# Successfully converted to json bytes
# Data for SEDA uploaded to S3: egdar_data/raw/2024-06-02/SEDA.json
# total companies uploaded: 2
# total tries: 3
# Successful CIK extraction for CTRN
# Successfully converted to json bytes
# Data for CTRN uploaded to S3: egdar_data/raw/2024-06-02/CTRN.json
# total companies uploaded: 3
# total tries: 4
# Successful CIK extraction for OVLY
# Successfully converted to json bytes
# Data for OVLY uploaded to S3: egdar_data/raw/2024-06-02/OVLY.json
# total companies uploaded: 4
# total tries: 5
# Successful CIK extraction for BKN
# Successfully converted to json bytes
# Data for BKN uploaded to S3: egdar_data/raw/2024-06-02/BKN.json
# total companies uploaded: 5
# total tries: 6
# Successful CIK extraction for DCTH
# Successfully converted to json bytes
# Data for DCTH uploaded to S3: egdar_data/raw/2024-06-02/DCTH.json
# total companies uploaded: 6
# total tries: 7
# Successful CIK extraction for ICTSF
# Successfully converted to json bytes
# Data for ICTSF uploaded to S3: egdar_data/raw/2024-06-02/ICTSF.json
# total companies uploaded: 7
# total tries: 8
# Successful CIK extraction for NTG
# HTTP error for NTG: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001490286.json
# total tries: 9
# Successful CIK extraction for PNRG
# Successfully converted to json bytes
# Data for PNRG uploaded to S3: egdar_data/raw/2024-06-02/PNRG.json
# total companies uploaded: 8
# total tries: 10
# Successful CIK extraction for BAER
# Successfully converted to json bytes
# Data for BAER uploaded to S3: egdar_data/raw/2024-06-02/BAER.json
# total companies uploaded: 9
# total tries: 11
# Successful CIK extraction for KGNR
# Successfully converted to json bytes
# Data for KGNR uploaded to S3: egdar_data/raw/2024-06-02/KGNR.json
# total companies uploaded: 10
# total tries: 12
# Successful CIK extraction for NWFL
# Successfully converted to json bytes
# Data for NWFL uploaded to S3: egdar_data/raw/2024-06-02/NWFL.json
# total companies uploaded: 11
# total tries: 13
# Successful CIK extraction for ETX
# Successfully converted to json bytes
# Data for ETX uploaded to S3: egdar_data/raw/2024-06-02/ETX.json
# total companies uploaded: 12
# total tries: 14
# Successful CIK extraction for FF
# Successfully converted to json bytes
# Data for FF uploaded to S3: egdar_data/raw/2024-06-02/FF.json
# total companies uploaded: 13
# total tries: 15
# Successful CIK extraction for ALCO
# Successfully converted to json bytes
# Data for ALCO uploaded to S3: egdar_data/raw/2024-06-02/ALCO.json
# total companies uploaded: 14
# total tries: 16
# Successful CIK extraction for CSTE
# Successfully converted to json bytes
# Data for CSTE uploaded to S3: egdar_data/raw/2024-06-02/CSTE.json
# total companies uploaded: 15
# total tries: 17
# Successful CIK extraction for OM
# Successfully converted to json bytes
# Data for OM uploaded to S3: egdar_data/raw/2024-06-02/OM.json
# total companies uploaded: 16
# total tries: 18
# Successful CIK extraction for CZFS
# Successfully converted to json bytes
# Data for CZFS uploaded to S3: egdar_data/raw/2024-06-02/CZFS.json
# total companies uploaded: 17
# total tries: 19
# Successful CIK extraction for IVVD
# Successfully converted to json bytes
# Data for IVVD uploaded to S3: egdar_data/raw/2024-06-02/IVVD.json
# total companies uploaded: 18
# total tries: 20
# Successful CIK extraction for ULBI
# Successfully converted to json bytes
# Data for ULBI uploaded to S3: egdar_data/raw/2024-06-02/ULBI.json
# total companies uploaded: 19
# total tries: 21
# Successful CIK extraction for FVCB
# Successfully converted to json bytes
# Data for FVCB uploaded to S3: egdar_data/raw/2024-06-02/FVCB.json
# total companies uploaded: 20
# total tries: 22
# Successful CIK extraction for ONL
# Successfully converted to json bytes
# Data for ONL uploaded to S3: egdar_data/raw/2024-06-02/ONL.json
# total companies uploaded: 21
# total tries: 23
# Successful CIK extraction for MHLD
# Successfully converted to json bytes
# Data for MHLD uploaded to S3: egdar_data/raw/2024-06-02/MHLD.json
# total companies uploaded: 22
# total tries: 24
# Successful CIK extraction for TWIN
# Successfully converted to json bytes
# Data for TWIN uploaded to S3: egdar_data/raw/2024-06-02/TWIN.json
# total companies uploaded: 23
# total tries: 25
# Successful CIK extraction for LCNB
# Successfully converted to json bytes
# Data for LCNB uploaded to S3: egdar_data/raw/2024-06-02/LCNB.json
# total companies uploaded: 24
# total tries: 26
# Successful CIK extraction for BOLD
# Successfully converted to json bytes
# Data for BOLD uploaded to S3: egdar_data/raw/2024-06-02/BOLD.json
# total companies uploaded: 25
# total tries: 27
# Successful CIK extraction for FFNW
# Successfully converted to json bytes
# Data for FFNW uploaded to S3: egdar_data/raw/2024-06-02/FFNW.json
# total companies uploaded: 26
# total tries: 28
# Successful CIK extraction for ASUR
# Successfully converted to json bytes
# Data for ASUR uploaded to S3: egdar_data/raw/2024-06-02/ASUR.json
# total companies uploaded: 27
# total tries: 29
# Successful CIK extraction for JAKK
# Successfully converted to json bytes
# Data for JAKK uploaded to S3: egdar_data/raw/2024-06-02/JAKK.json
# total companies uploaded: 28
# total tries: 30
# Successful CIK extraction for BWFG
# Successfully converted to json bytes
# Data for BWFG uploaded to S3: egdar_data/raw/2024-06-02/BWFG.json
# total companies uploaded: 29
# total tries: 31
# Successful CIK extraction for RMBL
# Successfully converted to json bytes
# Data for RMBL uploaded to S3: egdar_data/raw/2024-06-02/RMBL.json
# total companies uploaded: 30
# total tries: 32
# Successful CIK extraction for PLG
# Successfully converted to json bytes
# Data for PLG uploaded to S3: egdar_data/raw/2024-06-02/PLG.json
# total companies uploaded: 31
# total tries: 33
# Successful CIK extraction for INGN
# Successfully converted to json bytes
# Data for INGN uploaded to S3: egdar_data/raw/2024-06-02/INGN.json
# total companies uploaded: 32
# total tries: 34
# Successful CIK extraction for ITI
# Successfully converted to json bytes
# Data for ITI uploaded to S3: egdar_data/raw/2024-06-02/ITI.json
# total companies uploaded: 33
# total tries: 35
# Successful CIK extraction for BPRN
# Successfully converted to json bytes
# Data for BPRN uploaded to S3: egdar_data/raw/2024-06-02/BPRN.json
# total companies uploaded: 34
# total tries: 36
# Successful CIK extraction for QUIK
# Successfully converted to json bytes
# Data for QUIK uploaded to S3: egdar_data/raw/2024-06-02/QUIK.json
# total companies uploaded: 35
# total tries: 37
# Successful CIK extraction for ELLO
# Successfully converted to json bytes
# Data for ELLO uploaded to S3: egdar_data/raw/2024-06-02/ELLO.json
# total companies uploaded: 36
# total tries: 38
# Successful CIK extraction for LLAP
# Successfully converted to json bytes
# Data for LLAP uploaded to S3: egdar_data/raw/2024-06-02/LLAP.json
# total companies uploaded: 37
# total tries: 39
# Successful CIK extraction for FSP
# Successfully converted to json bytes
# Data for FSP uploaded to S3: egdar_data/raw/2024-06-02/FSP.json
# total companies uploaded: 38
# total tries: 40
# Successful CIK extraction for MITT
# Successfully converted to json bytes
# Data for MITT uploaded to S3: egdar_data/raw/2024-06-02/MITT.json
# total companies uploaded: 39
# total tries: 41
# Successful CIK extraction for NPCE
# Successfully converted to json bytes
# Data for NPCE uploaded to S3: egdar_data/raw/2024-06-02/NPCE.json
# total companies uploaded: 40
# total tries: 42
# Successful CIK extraction for BNIGF
# HTTP error for BNIGF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001851651.json
# total tries: 43
# Successful CIK extraction for INMB
# Successfully converted to json bytes
# Data for INMB uploaded to S3: egdar_data/raw/2024-06-02/INMB.json
# total companies uploaded: 41
# total tries: 44
# Successful CIK extraction for OMER
# Successfully converted to json bytes
# Data for OMER uploaded to S3: egdar_data/raw/2024-06-02/OMER.json
# total companies uploaded: 42
# total tries: 45
# Successful CIK extraction for HITI
# Successfully converted to json bytes
# Data for HITI uploaded to S3: egdar_data/raw/2024-06-02/HITI.json
# total companies uploaded: 43
# total tries: 46
# Successful CIK extraction for OPP
# Successfully converted to json bytes
# Data for OPP uploaded to S3: egdar_data/raw/2024-06-02/OPP.json
# total companies uploaded: 44
# total tries: 47
# Successful CIK extraction for MX
# Successfully converted to json bytes
# Data for MX uploaded to S3: egdar_data/raw/2024-06-02/MX.json
# total companies uploaded: 45
# total tries: 48
# Successful CIK extraction for PKBK
# Successfully converted to json bytes
# Data for PKBK uploaded to S3: egdar_data/raw/2024-06-02/PKBK.json
# total companies uploaded: 46
# total tries: 49
# Successful CIK extraction for MIO
# Successfully converted to json bytes
# Data for MIO uploaded to S3: egdar_data/raw/2024-06-02/MIO.json
# total companies uploaded: 47
# total tries: 50
# Successful CIK extraction for SMID
# Successfully converted to json bytes
# Data for SMID uploaded to S3: egdar_data/raw/2024-06-02/SMID.json
# total companies uploaded: 48
# total tries: 51
# Successful CIK extraction for MFIN
# Successfully converted to json bytes
# Data for MFIN uploaded to S3: egdar_data/raw/2024-06-02/MFIN.json
# total companies uploaded: 49
# total tries: 52
# Successful CIK extraction for OCN
# Successfully converted to json bytes
# Data for OCN uploaded to S3: egdar_data/raw/2024-06-02/OCN.json
# total companies uploaded: 50
# total tries: 53
# Successful CIK extraction for MAV
# HTTP error for MAV: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001258943.json
# total tries: 54
# Successful CIK extraction for PLNH
# Successfully converted to json bytes
# Data for PLNH uploaded to S3: egdar_data/raw/2024-06-02/PLNH.json
# total companies uploaded: 51
# total tries: 55
# Successful CIK extraction for ZVRA
# Successfully converted to json bytes
# Data for ZVRA uploaded to S3: egdar_data/raw/2024-06-02/ZVRA.json
# total companies uploaded: 52
# total tries: 56
# Successful CIK extraction for ESCA
# Successfully converted to json bytes
# Data for ESCA uploaded to S3: egdar_data/raw/2024-06-02/ESCA.json
# total companies uploaded: 53
# total tries: 57
# Successful CIK extraction for COFS
# Successfully converted to json bytes
# Data for COFS uploaded to S3: egdar_data/raw/2024-06-02/COFS.json
# total companies uploaded: 54
# total tries: 58
# Successful CIK extraction for KNIT
# Successfully converted to json bytes
# Data for KNIT uploaded to S3: egdar_data/raw/2024-06-02/KNIT.json
# total companies uploaded: 55
# total tries: 59
# Successful CIK extraction for PBYI
# Successfully converted to json bytes
# Data for PBYI uploaded to S3: egdar_data/raw/2024-06-02/PBYI.json
# total companies uploaded: 56
# total tries: 60
# Successful CIK extraction for DBP
# Successfully converted to json bytes
# Data for DBP uploaded to S3: egdar_data/raw/2024-06-02/DBP.json
# total companies uploaded: 57
# total tries: 61
# Successful CIK extraction for EMF
# HTTP error for EMF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000809708.json
# total tries: 62
# Successful CIK extraction for PRLD
# Successfully converted to json bytes
# Data for PRLD uploaded to S3: egdar_data/raw/2024-06-02/PRLD.json
# total companies uploaded: 58
# total tries: 63
# Successful CIK extraction for CIO
# Successfully converted to json bytes
# Data for CIO uploaded to S3: egdar_data/raw/2024-06-02/CIO.json
# total companies uploaded: 59
# total tries: 64
# Successful CIK extraction for NRGV
# Successfully converted to json bytes
# Data for NRGV uploaded to S3: egdar_data/raw/2024-06-02/NRGV.json
# total companies uploaded: 60
# total tries: 65
# Successful CIK extraction for APPS
# Successfully converted to json bytes
# Data for APPS uploaded to S3: egdar_data/raw/2024-06-02/APPS.json
# total companies uploaded: 61
# total tries: 66
# Successful CIK extraction for NPV
# HTTP error for NPV: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000897421.json
# total tries: 67
# Successful CIK extraction for LANV
# Successfully converted to json bytes
# Data for LANV uploaded to S3: egdar_data/raw/2024-06-02/LANV.json
# total companies uploaded: 62
# total tries: 68
# Successful CIK extraction for IVA
# Successfully converted to json bytes
# Data for IVA uploaded to S3: egdar_data/raw/2024-06-02/IVA.json
# total companies uploaded: 63
# total tries: 69
# Successful CIK extraction for VIRC
# Successfully converted to json bytes
# Data for VIRC uploaded to S3: egdar_data/raw/2024-06-02/VIRC.json
# total companies uploaded: 64
# total tries: 70
# Successful CIK extraction for STI
# Successfully converted to json bytes
# Data for STI uploaded to S3: egdar_data/raw/2024-06-02/STI.json
# total companies uploaded: 65
# total tries: 71
# Successful CIK extraction for NNE
# HTTP error for NNE: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001923891.json
# total tries: 72
# Successful CIK extraction for EPM
# Successfully converted to json bytes
# Data for EPM uploaded to S3: egdar_data/raw/2024-06-02/EPM.json
# total companies uploaded: 66
# total tries: 73
# Successful CIK extraction for SJT
# HTTP error for SJT: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000319655.json
# total tries: 74
# Successful CIK extraction for DM
# Successfully converted to json bytes
# Data for DM uploaded to S3: egdar_data/raw/2024-06-02/DM.json
# total companies uploaded: 67
# total tries: 75
# Successful CIK extraction for TG
# Successfully converted to json bytes
# Data for TG uploaded to S3: egdar_data/raw/2024-06-02/TG.json
# total companies uploaded: 68
# total tries: 76
# Successful CIK extraction for FENC
# Successfully converted to json bytes
# Data for FENC uploaded to S3: egdar_data/raw/2024-06-02/FENC.json
# total companies uploaded: 69
# total tries: 77
# Successful CIK extraction for ABOS
# Successfully converted to json bytes
# Data for ABOS uploaded to S3: egdar_data/raw/2024-06-02/ABOS.json
# total companies uploaded: 70
# total tries: 78
# Successful CIK extraction for ACHV
# Successfully converted to json bytes
# Data for ACHV uploaded to S3: egdar_data/raw/2024-06-02/ACHV.json
# total companies uploaded: 71
# total tries: 79
# Successful CIK extraction for EMP
# HTTP error for EMP: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000066901.json
# total tries: 80
# Successful CIK extraction for DMB
# HTTP error for DMB: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001565381.json
# total tries: 81
# Successful CIK extraction for WIA
# HTTP error for WIA: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001254370.json
# total tries: 82
# Successful CIK extraction for CALB
# Successfully converted to json bytes
# Data for CALB uploaded to S3: egdar_data/raw/2024-06-02/CALB.json
# total companies uploaded: 72
# total tries: 83
# Successful CIK extraction for XYF
# Successfully converted to json bytes
# Data for XYF uploaded to S3: egdar_data/raw/2024-06-02/XYF.json
# total companies uploaded: 73
# total tries: 84
# Successful CIK extraction for ELTP
# Successfully converted to json bytes
# Data for ELTP uploaded to S3: egdar_data/raw/2024-06-02/ELTP.json
# total companies uploaded: 74
# total tries: 85
# Successful CIK extraction for TELO
# Successfully converted to json bytes
# Data for TELO uploaded to S3: egdar_data/raw/2024-06-02/TELO.json
# total companies uploaded: 75
# total tries: 86
# Successful CIK extraction for IVCA
# Successfully converted to json bytes
# Data for IVCA uploaded to S3: egdar_data/raw/2024-06-02/IVCA.json
# total companies uploaded: 76
# total tries: 87
# Successful CIK extraction for PCK
# HTTP error for PCK: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001170300.json
# total tries: 88
# Successful CIK extraction for QRHC
# Successfully converted to json bytes
# Data for QRHC uploaded to S3: egdar_data/raw/2024-06-02/QRHC.json
# total companies uploaded: 77
# total tries: 89
# Successful CIK extraction for SANG
# Successfully converted to json bytes
# Data for SANG uploaded to S3: egdar_data/raw/2024-06-02/SANG.json
# total companies uploaded: 78
# total tries: 90
# Successful CIK extraction for RGTI
# Successfully converted to json bytes
# Data for RGTI uploaded to S3: egdar_data/raw/2024-06-02/RGTI.json
# total companies uploaded: 79
# total tries: 91
# Successful CIK extraction for CAPR
# Successfully converted to json bytes
# Data for CAPR uploaded to S3: egdar_data/raw/2024-06-02/CAPR.json
# total companies uploaded: 80
# total tries: 92
# Successful CIK extraction for GDO
# HTTP error for GDO: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001472341.json
# total tries: 93
# Successful CIK extraction for SBXC
# Successfully converted to json bytes
# Data for SBXC uploaded to S3: egdar_data/raw/2024-06-02/SBXC.json
# total companies uploaded: 81
# total tries: 94
# Successful CIK extraction for OXSQ
# Successfully converted to json bytes
# Data for OXSQ uploaded to S3: egdar_data/raw/2024-06-02/OXSQ.json
# total companies uploaded: 82
# total tries: 95
# Successful CIK extraction for SEVN
# Successfully converted to json bytes
# Data for SEVN uploaded to S3: egdar_data/raw/2024-06-02/SEVN.json
# total companies uploaded: 83
# total tries: 96
# Successful CIK extraction for FANH
# Successfully converted to json bytes
# Data for FANH uploaded to S3: egdar_data/raw/2024-06-02/FANH.json
# total companies uploaded: 84
# total tries: 97
# Successful CIK extraction for IGI
# HTTP error for IGI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001462586.json
# total tries: 98
# Successful CIK extraction for TRIS
# Successfully converted to json bytes
# Data for TRIS uploaded to S3: egdar_data/raw/2024-06-02/TRIS.json
# total companies uploaded: 85
# total tries: 99
# Successful CIK extraction for BSL
# HTTP error for BSL: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001486298.json
# total tries: 100
# Successful CIK extraction for KNDI
# HTTP error for KNDI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001720250.json
# total tries: 101
# Successful CIK extraction for OGI
# Successfully converted to json bytes
# Data for OGI uploaded to S3: egdar_data/raw/2024-06-02/OGI.json
# total companies uploaded: 86
# total tries: 102
# Successful CIK extraction for DTI
# Successfully converted to json bytes
# Data for DTI uploaded to S3: egdar_data/raw/2024-06-02/DTI.json
# total companies uploaded: 87
# total tries: 103
# Successful CIK extraction for PTMN
# Successfully converted to json bytes
# Data for PTMN uploaded to S3: egdar_data/raw/2024-06-02/PTMN.json
# total companies uploaded: 88
# total tries: 104
# Successful CIK extraction for PROF
# Successfully converted to json bytes
# Data for PROF uploaded to S3: egdar_data/raw/2024-06-02/PROF.json
# total companies uploaded: 89
# total tries: 105
# Successful CIK extraction for VNJA
# Successfully converted to json bytes
# Data for VNJA uploaded to S3: egdar_data/raw/2024-06-02/VNJA.json
# total companies uploaded: 90
# total tries: 106
# Successful CIK extraction for STRS
# Successfully converted to json bytes
# Data for STRS uploaded to S3: egdar_data/raw/2024-06-02/STRS.json
# total companies uploaded: 91
# total tries: 107
# Successful CIK extraction for TRVI
# Successfully converted to json bytes
# Data for TRVI uploaded to S3: egdar_data/raw/2024-06-02/TRVI.json
# total companies uploaded: 92
# total tries: 108
# Successful CIK extraction for INVZ
# Successfully converted to json bytes
# Data for INVZ uploaded to S3: egdar_data/raw/2024-06-02/INVZ.json
# total companies uploaded: 93
# total tries: 109
# Successful CIK extraction for LCTX
# Successfully converted to json bytes
# Data for LCTX uploaded to S3: egdar_data/raw/2024-06-02/LCTX.json
# total companies uploaded: 94
# total tries: 110
# Successful CIK extraction for FLXS
# Successfully converted to json bytes
# Data for FLXS uploaded to S3: egdar_data/raw/2024-06-02/FLXS.json
# total companies uploaded: 95
# total tries: 111
# Successful CIK extraction for ATLO
# Successfully converted to json bytes
# Data for ATLO uploaded to S3: egdar_data/raw/2024-06-02/ATLO.json
# total companies uploaded: 96
# total tries: 112
# Successful CIK extraction for APCA
# Successfully converted to json bytes
# Data for APCA uploaded to S3: egdar_data/raw/2024-06-02/APCA.json
# total companies uploaded: 97
# total tries: 113
# Successful CIK extraction for XTKG
# Successfully converted to json bytes
# Data for XTKG uploaded to S3: egdar_data/raw/2024-06-02/XTKG.json
# total companies uploaded: 98
# total tries: 114
# Successful CIK extraction for EGAN
# Successfully converted to json bytes
# Data for EGAN uploaded to S3: egdar_data/raw/2024-06-02/EGAN.json
# total companies uploaded: 99
# total tries: 115
# Successful CIK extraction for SNFCA
# Successfully converted to json bytes
# Data for SNFCA uploaded to S3: egdar_data/raw/2024-06-02/SNFCA.json
# total companies uploaded: 100
# total tries: 116
# Successful CIK extraction for VBF
# Successfully converted to json bytes
# Data for VBF uploaded to S3: egdar_data/raw/2024-06-02/VBF.json
# total companies uploaded: 101
# total tries: 117
# Successful CIK extraction for HFFG
# Successfully converted to json bytes
# Data for HFFG uploaded to S3: egdar_data/raw/2024-06-02/HFFG.json
# total companies uploaded: 102
# total tries: 118
# Successful CIK extraction for HQI
# Successfully converted to json bytes
# Data for HQI uploaded to S3: egdar_data/raw/2024-06-02/HQI.json
# total companies uploaded: 103
# total tries: 119
# Successful CIK extraction for NOTE
# Successfully converted to json bytes
# Data for NOTE uploaded to S3: egdar_data/raw/2024-06-02/NOTE.json
# total companies uploaded: 104
# total tries: 120
# Successful CIK extraction for ENJ
# HTTP error for ENJ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000071508.json
# total tries: 121
# Successful CIK extraction for CFNB
# Successfully converted to json bytes
# Data for CFNB uploaded to S3: egdar_data/raw/2024-06-02/CFNB.json
# total companies uploaded: 105
# total tries: 122
# Successful CIK extraction for UBXG
# Successfully converted to json bytes
# Data for UBXG uploaded to S3: egdar_data/raw/2024-06-02/UBXG.json
# total companies uploaded: 106
# total tries: 123
# Successful CIK extraction for HOFT
# Successfully converted to json bytes
# Data for HOFT uploaded to S3: egdar_data/raw/2024-06-02/HOFT.json
# total companies uploaded: 107
# total tries: 124
# Successful CIK extraction for BRLS
# Successfully converted to json bytes
# Data for BRLS uploaded to S3: egdar_data/raw/2024-06-02/BRLS.json
# total companies uploaded: 108
# total tries: 125
# Successful CIK extraction for DRTS
# Successfully converted to json bytes
# Data for DRTS uploaded to S3: egdar_data/raw/2024-06-02/DRTS.json
# total companies uploaded: 109
# total tries: 126
# Successful CIK extraction for HCVI
# Successfully converted to json bytes
# Data for HCVI uploaded to S3: egdar_data/raw/2024-06-02/HCVI.json
# total companies uploaded: 110
# total tries: 127
# Successful CIK extraction for GALT
# Successfully converted to json bytes
# Data for GALT uploaded to S3: egdar_data/raw/2024-06-02/GALT.json
# total companies uploaded: 111
# total tries: 128
# Successful CIK extraction for SGMT
# Successfully converted to json bytes
# Data for SGMT uploaded to S3: egdar_data/raw/2024-06-02/SGMT.json
# total companies uploaded: 112
# total tries: 129
# Successful CIK extraction for LFCR
# Successfully converted to json bytes
# Data for LFCR uploaded to S3: egdar_data/raw/2024-06-02/LFCR.json
# total companies uploaded: 113
# total tries: 130
# Successful CIK extraction for EML
# Successfully converted to json bytes
# Data for EML uploaded to S3: egdar_data/raw/2024-06-02/EML.json
# total companies uploaded: 114
# total tries: 131
# Successful CIK extraction for BLUE
# Successfully converted to json bytes
# Data for BLUE uploaded to S3: egdar_data/raw/2024-06-02/BLUE.json
# total companies uploaded: 115
# total tries: 132
# Successful CIK extraction for MBCN
# Successfully converted to json bytes
# Data for MBCN uploaded to S3: egdar_data/raw/2024-06-02/MBCN.json
# total companies uploaded: 116
# total tries: 133
# Successful CIK extraction for TUSK
# Successfully converted to json bytes
# Data for TUSK uploaded to S3: egdar_data/raw/2024-06-02/TUSK.json
# total companies uploaded: 117
# total tries: 134
# Successful CIK extraction for PPYA
# Successfully converted to json bytes
# Data for PPYA uploaded to S3: egdar_data/raw/2024-06-02/PPYA.json
# total companies uploaded: 118
# total tries: 135
# Successful CIK extraction for FLL
# Successfully converted to json bytes
# Data for FLL uploaded to S3: egdar_data/raw/2024-06-02/FLL.json
# total companies uploaded: 119
# total tries: 136
# Successful CIK extraction for ODV
# Successfully converted to json bytes
# Data for ODV uploaded to S3: egdar_data/raw/2024-06-02/ODV.json
# total companies uploaded: 120
# total tries: 137
# Successful CIK extraction for GLSI
# Successfully converted to json bytes
# Data for GLSI uploaded to S3: egdar_data/raw/2024-06-02/GLSI.json
# total companies uploaded: 121
# total tries: 138
# Successful CIK extraction for LSB
# Successfully converted to json bytes
# Data for LSB uploaded to S3: egdar_data/raw/2024-06-02/LSB.json
# total companies uploaded: 122
# total tries: 139
# Successful CIK extraction for TLYS
# Successfully converted to json bytes
# Data for TLYS uploaded to S3: egdar_data/raw/2024-06-02/TLYS.json
# total companies uploaded: 123
# total tries: 140
# Successful CIK extraction for OTLK
# Successfully converted to json bytes
# Data for OTLK uploaded to S3: egdar_data/raw/2024-06-02/OTLK.json
# total companies uploaded: 124
# total tries: 141
# Successful CIK extraction for SCWO
# Successfully converted to json bytes
# Data for SCWO uploaded to S3: egdar_data/raw/2024-06-02/SCWO.json
# total companies uploaded: 125
# total tries: 142
# Successful CIK extraction for SOWG
# Successfully converted to json bytes
# Data for SOWG uploaded to S3: egdar_data/raw/2024-06-02/SOWG.json
# total companies uploaded: 126
# total tries: 143
# Successful CIK extraction for THCH
# Successfully converted to json bytes
# Data for THCH uploaded to S3: egdar_data/raw/2024-06-02/THCH.json
# total companies uploaded: 127
# total tries: 144
# Successful CIK extraction for DHF
# Successfully converted to json bytes
# Data for DHF uploaded to S3: egdar_data/raw/2024-06-02/DHF.json
# total companies uploaded: 128
# total tries: 145
# Successful CIK extraction for EVC
# Successfully converted to json bytes
# Data for EVC uploaded to S3: egdar_data/raw/2024-06-02/EVC.json
# total companies uploaded: 129
# total tries: 146
# Successful CIK extraction for PCQ
# HTTP error for PCQ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001140411.json
# total tries: 147
# Successful CIK extraction for ESSA
# Successfully converted to json bytes
# Data for ESSA uploaded to S3: egdar_data/raw/2024-06-02/ESSA.json
# total companies uploaded: 130
# total tries: 148
# Successful CIK extraction for TRVG
# Successfully converted to json bytes
# Data for TRVG uploaded to S3: egdar_data/raw/2024-06-02/TRVG.json
# total companies uploaded: 131
# total tries: 149
# Successful CIK extraction for GTHX
# Successfully converted to json bytes
# Data for GTHX uploaded to S3: egdar_data/raw/2024-06-02/GTHX.json
# total companies uploaded: 132
# total tries: 150
# Successful CIK extraction for EACO
# Successfully converted to json bytes
# Data for EACO uploaded to S3: egdar_data/raw/2024-06-02/EACO.json
# total companies uploaded: 133
# total tries: 151
# Successful CIK extraction for ENX
# Successfully converted to json bytes
# Data for ENX uploaded to S3: egdar_data/raw/2024-06-02/ENX.json
# total companies uploaded: 134
# total tries: 152
# Successful CIK extraction for KLTR
# Successfully converted to json bytes
# Data for KLTR uploaded to S3: egdar_data/raw/2024-06-02/KLTR.json
# total companies uploaded: 135
# total tries: 153
# Successful CIK extraction for BZUN
# Successfully converted to json bytes
# Data for BZUN uploaded to S3: egdar_data/raw/2024-06-02/BZUN.json
# total companies uploaded: 136
# total tries: 154
# Successful CIK extraction for NAK
# Successfully converted to json bytes
# Data for NAK uploaded to S3: egdar_data/raw/2024-06-02/NAK.json
# total companies uploaded: 137
# total tries: 155
# Successful CIK extraction for MAXN
# Successfully converted to json bytes
# Data for MAXN uploaded to S3: egdar_data/raw/2024-06-02/MAXN.json
# total companies uploaded: 138
# total tries: 156
# Successful CIK extraction for ABEO
# Successfully converted to json bytes
# Data for ABEO uploaded to S3: egdar_data/raw/2024-06-02/ABEO.json
# total companies uploaded: 139
# total tries: 157
# Successful CIK extraction for SPKL
# Successfully converted to json bytes
# Data for SPKL uploaded to S3: egdar_data/raw/2024-06-02/SPKL.json
# total companies uploaded: 140
# total tries: 158
# Successful CIK extraction for SKGR
# Successfully converted to json bytes
# Data for SKGR uploaded to S3: egdar_data/raw/2024-06-02/SKGR.json
# total companies uploaded: 141
# total tries: 159
# Successful CIK extraction for NTIC
# Successfully converted to json bytes
# Data for NTIC uploaded to S3: egdar_data/raw/2024-06-02/NTIC.json
# total companies uploaded: 142
# total tries: 160
# Successful CIK extraction for PLCE
# Successfully converted to json bytes
# Data for PLCE uploaded to S3: egdar_data/raw/2024-06-02/PLCE.json
# total companies uploaded: 143
# total tries: 161
# Successful CIK extraction for MPV
# HTTP error for MPV: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000831655.json
# total tries: 162
# Successful CIK extraction for CVGI
# Successfully converted to json bytes
# Data for CVGI uploaded to S3: egdar_data/raw/2024-06-02/CVGI.json
# total companies uploaded: 144
# total tries: 163
# Successful CIK extraction for FT
# HTTP error for FT: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000833040.json
# total tries: 164
# Successful CIK extraction for PIIVX
# Successfully converted to json bytes
# Data for PIIVX uploaded to S3: egdar_data/raw/2024-06-02/PIIVX.json
# total companies uploaded: 145
# total tries: 165
# Successful CIK extraction for WTO
# Successfully converted to json bytes
# Data for WTO uploaded to S3: egdar_data/raw/2024-06-02/WTO.json
# total companies uploaded: 146
# total tries: 166
# Successful CIK extraction for GLDG
# Successfully converted to json bytes
# Data for GLDG uploaded to S3: egdar_data/raw/2024-06-02/GLDG.json
# total companies uploaded: 147
# total tries: 167
# Successful CIK extraction for EHTH
# Successfully converted to json bytes
# Data for EHTH uploaded to S3: egdar_data/raw/2024-06-02/EHTH.json
# total companies uploaded: 148
# total tries: 168
# Successful CIK extraction for AEVA
# Successfully converted to json bytes
# Data for AEVA uploaded to S3: egdar_data/raw/2024-06-02/AEVA.json
# total companies uploaded: 149
# total tries: 169
# Successful CIK extraction for NKSH
# Successfully converted to json bytes
# Data for NKSH uploaded to S3: egdar_data/raw/2024-06-02/NKSH.json
# total companies uploaded: 150
# total tries: 170
# Successful CIK extraction for BRKH
# Successfully converted to json bytes
# Data for BRKH uploaded to S3: egdar_data/raw/2024-06-02/BRKH.json
# total companies uploaded: 151
# total tries: 171
# Successful CIK extraction for INSI
# Successfully converted to json bytes
# Data for INSI uploaded to S3: egdar_data/raw/2024-06-02/INSI.json
# total companies uploaded: 152
# total tries: 172
# Successful CIK extraction for ALIM
# Successfully converted to json bytes
# Data for ALIM uploaded to S3: egdar_data/raw/2024-06-02/ALIM.json
# total companies uploaded: 153
# total tries: 173
# Successful CIK extraction for ORGN
# Successfully converted to json bytes
# Data for ORGN uploaded to S3: egdar_data/raw/2024-06-02/ORGN.json
# total companies uploaded: 154
# total tries: 174
# Successful CIK extraction for CRVO
# Successfully converted to json bytes
# Data for CRVO uploaded to S3: egdar_data/raw/2024-06-02/CRVO.json
# total companies uploaded: 155
# total tries: 175
# Successful CIK extraction for VERY
# Successfully converted to json bytes
# Data for VERY uploaded to S3: egdar_data/raw/2024-06-02/VERY.json
# total companies uploaded: 156
# total tries: 176
# Successful CIK extraction for CMCM
# Successfully converted to json bytes
# Data for CMCM uploaded to S3: egdar_data/raw/2024-06-02/CMCM.json
# total companies uploaded: 157
# total tries: 177
# Successful CIK extraction for HGLB
# HTTP error for HGLB: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001622148.json
# total tries: 178
# Successful CIK extraction for CMT
# Successfully converted to json bytes
# Data for CMT uploaded to S3: egdar_data/raw/2024-06-02/CMT.json
# total companies uploaded: 158
# total tries: 179
# Successful CIK extraction for HYB
# HTTP error for HYB: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000825345.json
# total tries: 180
# Successful CIK extraction for BCBP
# Successfully converted to json bytes
# Data for BCBP uploaded to S3: egdar_data/raw/2024-06-02/BCBP.json
# total companies uploaded: 159
# total tries: 181
# Successful CIK extraction for BXSY
# HTTP error for BXSY: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001059213.json
# total tries: 182
# Successful CIK extraction for AXTI
# Successfully converted to json bytes
# Data for AXTI uploaded to S3: egdar_data/raw/2024-06-02/AXTI.json
# total companies uploaded: 160
# total tries: 183
# Successful CIK extraction for CPSS
# Successfully converted to json bytes
# Data for CPSS uploaded to S3: egdar_data/raw/2024-06-02/CPSS.json
# total companies uploaded: 161
# total tries: 184
# Successful CIK extraction for DXYZ
# HTTP error for DXYZ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001843974.json
# total tries: 185
# Successful CIK extraction for TSQ
# Successfully converted to json bytes
# Data for TSQ uploaded to S3: egdar_data/raw/2024-06-02/TSQ.json
# total companies uploaded: 162
# total tries: 186
# Successful CIK extraction for GEVO
# Successfully converted to json bytes
# Data for GEVO uploaded to S3: egdar_data/raw/2024-06-02/GEVO.json
# total companies uploaded: 163
# total tries: 187
# Successful CIK extraction for ATOS
# Successfully converted to json bytes
# Data for ATOS uploaded to S3: egdar_data/raw/2024-06-02/ATOS.json
# total companies uploaded: 164
# total tries: 188
# Successful CIK extraction for FNGR
# Successfully converted to json bytes
# Data for FNGR uploaded to S3: egdar_data/raw/2024-06-02/FNGR.json
# total companies uploaded: 165
# total tries: 189
# Successful CIK extraction for STKS
# Successfully converted to json bytes
# Data for STKS uploaded to S3: egdar_data/raw/2024-06-02/STKS.json
# total companies uploaded: 166
# total tries: 190
# Successful CIK extraction for CRDL
# Successfully converted to json bytes
# Data for CRDL uploaded to S3: egdar_data/raw/2024-06-02/CRDL.json
# total companies uploaded: 167
# total tries: 191
# Successful CIK extraction for STXS
# Successfully converted to json bytes
# Data for STXS uploaded to S3: egdar_data/raw/2024-06-02/STXS.json
# total companies uploaded: 168
# total tries: 192
# Successful CIK extraction for RELL
# Successfully converted to json bytes
# Data for RELL uploaded to S3: egdar_data/raw/2024-06-02/RELL.json
# total companies uploaded: 169
# total tries: 193
# Successful CIK extraction for AHG
# Successfully converted to json bytes
# Data for AHG uploaded to S3: egdar_data/raw/2024-06-02/AHG.json
# total companies uploaded: 170
# total tries: 194
# Successful CIK extraction for LCW
# Successfully converted to json bytes
# Data for LCW uploaded to S3: egdar_data/raw/2024-06-02/LCW.json
# total companies uploaded: 171
# total tries: 195
# Successful CIK extraction for STHO
# Successfully converted to json bytes
# Data for STHO uploaded to S3: egdar_data/raw/2024-06-02/STHO.json
# total companies uploaded: 172
# total tries: 196
# Successful CIK extraction for ZOM
# Successfully converted to json bytes
# Data for ZOM uploaded to S3: egdar_data/raw/2024-06-02/ZOM.json
# total companies uploaded: 173
# total tries: 197
# Successful CIK extraction for MCAA
# Successfully converted to json bytes
# Data for MCAA uploaded to S3: egdar_data/raw/2024-06-02/MCAA.json
# total companies uploaded: 174
# total tries: 198
# Successful CIK extraction for LVO
# Successfully converted to json bytes
# Data for LVO uploaded to S3: egdar_data/raw/2024-06-02/LVO.json
# total companies uploaded: 175
# total tries: 199
# Successful CIK extraction for ADVM
# Successfully converted to json bytes
# Data for ADVM uploaded to S3: egdar_data/raw/2024-06-02/ADVM.json
# total companies uploaded: 176
# total tries: 200
# Successful CIK extraction for SST
# Successfully converted to json bytes
# Data for SST uploaded to S3: egdar_data/raw/2024-06-02/SST.json
# total companies uploaded: 177
# total tries: 201
# Successful CIK extraction for CRNC
# Successfully converted to json bytes
# Data for CRNC uploaded to S3: egdar_data/raw/2024-06-02/CRNC.json
# total companies uploaded: 178
# total tries: 202
# Successful CIK extraction for CBH
# HTTP error for CBH: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001701809.json
# total tries: 203
# Successful CIK extraction for MYFW
# Successfully converted to json bytes
# Data for MYFW uploaded to S3: egdar_data/raw/2024-06-02/MYFW.json
# total companies uploaded: 179
# total tries: 204
# Successful CIK extraction for PVBC
# Successfully converted to json bytes
# Data for PVBC uploaded to S3: egdar_data/raw/2024-06-02/PVBC.json
# total companies uploaded: 180
# total tries: 205
# Successful CIK extraction for SFWL
# Successfully converted to json bytes
# Data for SFWL uploaded to S3: egdar_data/raw/2024-06-02/SFWL.json
# total companies uploaded: 181
# total tries: 206
# Successful CIK extraction for NFYS
# Successfully converted to json bytes
# Data for NFYS uploaded to S3: egdar_data/raw/2024-06-02/NFYS.json
# total companies uploaded: 182
# total tries: 207
# Successful CIK extraction for VYEY
# Successfully converted to json bytes
# Data for VYEY uploaded to S3: egdar_data/raw/2024-06-02/VYEY.json
# total companies uploaded: 183
# total tries: 208
# Successful CIK extraction for HMST
# Successfully converted to json bytes
# Data for HMST uploaded to S3: egdar_data/raw/2024-06-02/HMST.json
# total companies uploaded: 184
# total tries: 209
# Successful CIK extraction for EDF
# Successfully converted to json bytes
# Data for EDF uploaded to S3: egdar_data/raw/2024-06-02/EDF.json
# total companies uploaded: 185
# total tries: 210
# Successful CIK extraction for LDDD
# Successfully converted to json bytes
# Data for LDDD uploaded to S3: egdar_data/raw/2024-06-02/LDDD.json
# total companies uploaded: 186
# total tries: 211
# Successful CIK extraction for MRCC
# Successfully converted to json bytes
# Data for MRCC uploaded to S3: egdar_data/raw/2024-06-02/MRCC.json
# total companies uploaded: 187
# total tries: 212
# Successful CIK extraction for RIGL
# Successfully converted to json bytes
# Data for RIGL uploaded to S3: egdar_data/raw/2024-06-02/RIGL.json
# total companies uploaded: 188
# total tries: 213
# Successful CIK extraction for BDSX
# Successfully converted to json bytes
# Data for BDSX uploaded to S3: egdar_data/raw/2024-06-02/BDSX.json
# total companies uploaded: 189
# total tries: 214
# Successful CIK extraction for MTWO
# Successfully converted to json bytes
# Data for MTWO uploaded to S3: egdar_data/raw/2024-06-02/MTWO.json
# total companies uploaded: 190
# total tries: 215
# Successful CIK extraction for GGT
# Successfully converted to json bytes
# Data for GGT uploaded to S3: egdar_data/raw/2024-06-02/GGT.json
# total companies uploaded: 191
# total tries: 216
# Successful CIK extraction for RYDE
# Successfully converted to json bytes
# Data for RYDE uploaded to S3: egdar_data/raw/2024-06-02/RYDE.json
# total companies uploaded: 192
# total tries: 217
# Successful CIK extraction for ALCY
# Successfully converted to json bytes
# Data for ALCY uploaded to S3: egdar_data/raw/2024-06-02/ALCY.json
# total companies uploaded: 193
# total tries: 218
# Successful CIK extraction for NHHS
# Successfully converted to json bytes
# Data for NHHS uploaded to S3: egdar_data/raw/2024-06-02/NHHS.json
# total companies uploaded: 194
# total tries: 219
# Successful CIK extraction for VABK
# Successfully converted to json bytes
# Data for VABK uploaded to S3: egdar_data/raw/2024-06-02/VABK.json
# total companies uploaded: 195
# total tries: 220
# Successful CIK extraction for EVE
# Successfully converted to json bytes
# Data for EVE uploaded to S3: egdar_data/raw/2024-06-02/EVE.json
# total companies uploaded: 196
# total tries: 221
# Successful CIK extraction for BFAC
# Successfully converted to json bytes
# Data for BFAC uploaded to S3: egdar_data/raw/2024-06-02/BFAC.json
# total companies uploaded: 197
# total tries: 222
# Successful CIK extraction for CLPR
# Successfully converted to json bytes
# Data for CLPR uploaded to S3: egdar_data/raw/2024-06-02/CLPR.json
# total companies uploaded: 198
# total tries: 223
# Successful CIK extraction for CANG
# Successfully converted to json bytes
# Data for CANG uploaded to S3: egdar_data/raw/2024-06-02/CANG.json
# total companies uploaded: 199
# total tries: 224
# Successful CIK extraction for XFOR
# Successfully converted to json bytes
# Data for XFOR uploaded to S3: egdar_data/raw/2024-06-02/XFOR.json
# total companies uploaded: 200
# total tries: 225
# Successful CIK extraction for DLHC
# Successfully converted to json bytes
# Data for DLHC uploaded to S3: egdar_data/raw/2024-06-02/DLHC.json
# total companies uploaded: 201
# total tries: 226
# Successful CIK extraction for BGX
# Successfully converted to json bytes
# Data for BGX uploaded to S3: egdar_data/raw/2024-06-02/BGX.json
# total companies uploaded: 202
# total tries: 227
# Successful CIK extraction for PEBK
# Successfully converted to json bytes
# Data for PEBK uploaded to S3: egdar_data/raw/2024-06-02/PEBK.json
# total companies uploaded: 203
# total tries: 228
# Successful CIK extraction for INFU
# Successfully converted to json bytes
# Data for INFU uploaded to S3: egdar_data/raw/2024-06-02/INFU.json
# total companies uploaded: 204
# total tries: 229
# Successful CIK extraction for MAPS
# Successfully converted to json bytes
# Data for MAPS uploaded to S3: egdar_data/raw/2024-06-02/MAPS.json
# total companies uploaded: 205
# total tries: 230
# Successful CIK extraction for RZLT
# Successfully converted to json bytes
# Data for RZLT uploaded to S3: egdar_data/raw/2024-06-02/RZLT.json
# total companies uploaded: 206
# total tries: 231
# Successful CIK extraction for BKSY
# Successfully converted to json bytes
# Data for BKSY uploaded to S3: egdar_data/raw/2024-06-02/BKSY.json
# total companies uploaded: 207
# total tries: 232
# Successful CIK extraction for TEAF
# HTTP error for TEAF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001704299.json
# total tries: 233
# Successful CIK extraction for PEGR
# Successfully converted to json bytes
# Data for PEGR uploaded to S3: egdar_data/raw/2024-06-02/PEGR.json
# total companies uploaded: 208
# total tries: 234
# Successful CIK extraction for IBAC
# Successfully converted to json bytes
# Data for IBAC uploaded to S3: egdar_data/raw/2024-06-02/IBAC.json
# total companies uploaded: 209
# total tries: 235
# Successful CIK extraction for FLC
# Successfully converted to json bytes
# Data for FLC uploaded to S3: egdar_data/raw/2024-06-02/FLC.json
# total companies uploaded: 210
# total tries: 236
# Successful CIK extraction for IDE
# HTTP error for IDE: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001417802.json
# total tries: 237
# Successful CIK extraction for ARAY
# Successfully converted to json bytes
# Data for ARAY uploaded to S3: egdar_data/raw/2024-06-02/ARAY.json
# total companies uploaded: 211
# total tries: 238
# Successful CIK extraction for CLPT
# Successfully converted to json bytes
# Data for CLPT uploaded to S3: egdar_data/raw/2024-06-02/CLPT.json
# total companies uploaded: 212
# total tries: 239
# Successful CIK extraction for EHI
# Successfully converted to json bytes
# Data for EHI uploaded to S3: egdar_data/raw/2024-06-02/EHI.json
# total companies uploaded: 213
# total tries: 240
# Successful CIK extraction for RCMT
# Successfully converted to json bytes
# Data for RCMT uploaded to S3: egdar_data/raw/2024-06-02/RCMT.json
# total companies uploaded: 214
# total tries: 241
# Successful CIK extraction for PZC
# HTTP error for PZC: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001181504.json
# total tries: 242
# Successful CIK extraction for NIU
# Successfully converted to json bytes
# Data for NIU uploaded to S3: egdar_data/raw/2024-06-02/NIU.json
# total companies uploaded: 215
# total tries: 243
# Successful CIK extraction for GOEV
# Successfully converted to json bytes
# Data for GOEV uploaded to S3: egdar_data/raw/2024-06-02/GOEV.json
# total companies uploaded: 216
# total tries: 244
# Successful CIK extraction for ISTR
# Successfully converted to json bytes
# Data for ISTR uploaded to S3: egdar_data/raw/2024-06-02/ISTR.json
# total companies uploaded: 217
# total tries: 245
# Successful CIK extraction for KOD
# Successfully converted to json bytes
# Data for KOD uploaded to S3: egdar_data/raw/2024-06-02/KOD.json
# total companies uploaded: 218
# total tries: 246
# Successful CIK extraction for PROP
# Successfully converted to json bytes
# Data for PROP uploaded to S3: egdar_data/raw/2024-06-02/PROP.json
# total companies uploaded: 219
# total tries: 247
# Successful CIK extraction for CIK
# Successfully converted to json bytes
# Data for CIK uploaded to S3: egdar_data/raw/2024-06-02/CIK.json
# total companies uploaded: 220
# total tries: 248
# Successful CIK extraction for NNBR
# Successfully converted to json bytes
# Data for NNBR uploaded to S3: egdar_data/raw/2024-06-02/NNBR.json
# total companies uploaded: 221
# total tries: 249
# Successful CIK extraction for ZENV
# Successfully converted to json bytes
# Data for ZENV uploaded to S3: egdar_data/raw/2024-06-02/ZENV.json
# total companies uploaded: 222
# total tries: 250
# Successful CIK extraction for III
# Successfully converted to json bytes
# Data for III uploaded to S3: egdar_data/raw/2024-06-02/III.json
# total companies uploaded: 223
# total tries: 251
# Successful CIK extraction for TATT
# Successfully converted to json bytes
# Data for TATT uploaded to S3: egdar_data/raw/2024-06-02/TATT.json
# total companies uploaded: 224
# total tries: 252
# Successful CIK extraction for QSG
# Successfully converted to json bytes
# Data for QSG uploaded to S3: egdar_data/raw/2024-06-02/QSG.json
# total companies uploaded: 225
# total tries: 253
# Successful CIK extraction for AMTX
# Successfully converted to json bytes
# Data for AMTX uploaded to S3: egdar_data/raw/2024-06-02/AMTX.json
# total companies uploaded: 226
# total tries: 254
# Successful CIK extraction for EMLD
# Successfully converted to json bytes
# Data for EMLD uploaded to S3: egdar_data/raw/2024-06-02/EMLD.json
# total companies uploaded: 227
# total tries: 255
# Successful CIK extraction for MPA
# HTTP error for MPA: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000891038.json
# total tries: 256
# Successful CIK extraction for ESHA
# Successfully converted to json bytes
# Data for ESHA uploaded to S3: egdar_data/raw/2024-06-02/ESHA.json
# total companies uploaded: 228
# total tries: 257
# Successful CIK extraction for CIA
# Successfully converted to json bytes
# Data for CIA uploaded to S3: egdar_data/raw/2024-06-02/CIA.json
# total companies uploaded: 229
# total tries: 258
# Successful CIK extraction for NNY
# HTTP error for NNY: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000818850.json
# total tries: 259
# Successful CIK extraction for MCN
# HTTP error for MCN: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001289868.json
# total tries: 260
# Successful CIK extraction for MDWD
# Successfully converted to json bytes
# Data for MDWD uploaded to S3: egdar_data/raw/2024-06-02/MDWD.json
# total companies uploaded: 230
# total tries: 261
# Successful CIK extraction for CAPT
# Successfully converted to json bytes
# Data for CAPT uploaded to S3: egdar_data/raw/2024-06-02/CAPT.json
# total companies uploaded: 231
# total tries: 262
# Successful CIK extraction for CVRX
# Successfully converted to json bytes
# Data for CVRX uploaded to S3: egdar_data/raw/2024-06-02/CVRX.json
# total companies uploaded: 232
# total tries: 263
# Successful CIK extraction for GRWG
# Successfully converted to json bytes
# Data for GRWG uploaded to S3: egdar_data/raw/2024-06-02/GRWG.json
# total companies uploaded: 233
# ...
# total tries: 413
# Successful CIK extraction for EVGR
# Successfully converted to json bytes
# Data for EVGR uploaded to S3: egdar_data/raw/2024-06-02/EVGR.json
# total companies uploaded: 369
# total tries: 414
# Successful CIK extraction for NAZ
# HTTP error for NAZ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000892992.json
# total tries: 415
# Successful CIK extraction for KGEI
# Successfully converted to json bytes
# Data for KGEI uploaded to S3: egdar_data/raw/2024-06-02/KGEI.json
# total companies uploaded: 370
# total tries: 416
# Successful CIK extraction for DBVT
# Successfully converted to json bytes
# Data for DBVT uploaded to S3: egdar_data/raw/2024-06-02/DBVT.json
# total companies uploaded: 371
# total tries: 417
# Successful CIK extraction for KBLB
# Successfully converted to json bytes
# Data for KBLB uploaded to S3: egdar_data/raw/2024-06-02/KBLB.json
# total companies uploaded: 372
# total tries: 418
# Successful CIK extraction for RMGCF
# Successfully converted to json bytes
# Data for RMGCF uploaded to S3: egdar_data/raw/2024-06-02/RMGCF.json
# total companies uploaded: 373
# total tries: 419
# Successful CIK extraction for BCG
# Successfully converted to json bytes
# Data for BCG uploaded to S3: egdar_data/raw/2024-06-02/BCG.json
# total companies uploaded: 374
# total tries: 420
# Successful CIK extraction for FRD
# Successfully converted to json bytes
# Data for FRD uploaded to S3: egdar_data/raw/2024-06-02/FRD.json
# total companies uploaded: 375
# total tries: 421
# Successful CIK extraction for OPTN
# Successfully converted to json bytes
# Data for OPTN uploaded to S3: egdar_data/raw/2024-06-02/OPTN.json
# total companies uploaded: 376
# total tries: 422
# Successful CIK extraction for CNXX
# Successfully converted to json bytes
# Data for CNXX uploaded to S3: egdar_data/raw/2024-06-02/CNXX.json
# total companies uploaded: 377
# total tries: 423
# Successful CIK extraction for ELA
# Successfully converted to json bytes
# Data for ELA uploaded to S3: egdar_data/raw/2024-06-02/ELA.json
# total companies uploaded: 378
# total tries: 424
# Successful CIK extraction for UFI
# Successfully converted to json bytes
# Data for UFI uploaded to S3: egdar_data/raw/2024-06-02/UFI.json
# total companies uploaded: 379
# total tries: 425
# Successful CIK extraction for FREVS
# Successfully converted to json bytes
# Data for FREVS uploaded to S3: egdar_data/raw/2024-06-02/FREVS.json
# total companies uploaded: 380
# total tries: 426
# Successful CIK extraction for CFBK
# Successfully converted to json bytes
# Data for CFBK uploaded to S3: egdar_data/raw/2024-06-02/CFBK.json
# total companies uploaded: 381
# total tries: 427
# Successful CIK extraction for GLQ
# HTTP error for GLQ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001316463.json
# total tries: 428
# Successful CIK extraction for CATO
# Successfully converted to json bytes
# Data for CATO uploaded to S3: egdar_data/raw/2024-06-02/CATO.json
# total companies uploaded: 382
# total tries: 429
# Successful CIK extraction for SRV
# Successfully converted to json bytes
# Data for SRV uploaded to S3: egdar_data/raw/2024-06-02/SRV.json
# total companies uploaded: 383
# total tries: 430
# Successful CIK extraction for IFIN
# Successfully converted to json bytes
# Data for IFIN uploaded to S3: egdar_data/raw/2024-06-02/IFIN.json
# total companies uploaded: 384
# total tries: 431
# Successful CIK extraction for FBYD
# Successfully converted to json bytes
# Data for FBYD uploaded to S3: egdar_data/raw/2024-06-02/FBYD.json
# total companies uploaded: 385
# total tries: 432
# Successful CIK extraction for ACET
# Successfully converted to json bytes
# Data for ACET uploaded to S3: egdar_data/raw/2024-06-02/ACET.json
# total companies uploaded: 386
# total tries: 433
# Successful CIK extraction for PHX
# Successfully converted to json bytes
# Data for PHX uploaded to S3: egdar_data/raw/2024-06-02/PHX.json
# total companies uploaded: 387
# total tries: 434
# Successful CIK extraction for VFL
# Successfully converted to json bytes
# Data for VFL uploaded to S3: egdar_data/raw/2024-06-02/VFL.json
# total companies uploaded: 388
# total tries: 435
# Successful CIK extraction for BOCN
# Successfully converted to json bytes
# Data for BOCN uploaded to S3: egdar_data/raw/2024-06-02/BOCN.json
# total companies uploaded: 389
# total tries: 436
# Successful CIK extraction for NVCT
# Successfully converted to json bytes
# Data for NVCT uploaded to S3: egdar_data/raw/2024-06-02/NVCT.json
# total companies uploaded: 390
# total tries: 437
# Successful CIK extraction for FTCO
# Successfully converted to json bytes
# Data for FTCO uploaded to S3: egdar_data/raw/2024-06-02/FTCO.json
# total companies uploaded: 391
# total tries: 438
# Successful CIK extraction for LOOP
# Successfully converted to json bytes
# Data for LOOP uploaded to S3: egdar_data/raw/2024-06-02/LOOP.json
# total companies uploaded: 392
# total tries: 439
# Successful CIK extraction for TWLV
# Successfully converted to json bytes
# Data for TWLV uploaded to S3: egdar_data/raw/2024-06-02/TWLV.json
# total companies uploaded: 393
# total tries: 440
# Successful CIK extraction for FXY
# Successfully converted to json bytes
# Data for FXY uploaded to S3: egdar_data/raw/2024-06-02/FXY.json
# total companies uploaded: 394
# total tries: 441
# Successful CIK extraction for AMWL
# Successfully converted to json bytes
# Data for AMWL uploaded to S3: egdar_data/raw/2024-06-02/AMWL.json
# total companies uploaded: 395
# total tries: 442
# Successful CIK extraction for JUSHF
# Successfully converted to json bytes
# Data for JUSHF uploaded to S3: egdar_data/raw/2024-06-02/JUSHF.json
# total companies uploaded: 396
# total tries: 443
# Successful CIK extraction for CZWI
# Successfully converted to json bytes
# Data for CZWI uploaded to S3: egdar_data/raw/2024-06-02/CZWI.json
# total companies uploaded: 397
# total tries: 444
# Successful CIK extraction for ATOM
# Successfully converted to json bytes
# Data for ATOM uploaded to S3: egdar_data/raw/2024-06-02/ATOM.json
# total companies uploaded: 398
# total tries: 445
# Successful CIK extraction for HNVR
# Successfully converted to json bytes
# Data for HNVR uploaded to S3: egdar_data/raw/2024-06-02/HNVR.json
# total companies uploaded: 399
# total tries: 446
# Successful CIK extraction for KEQU
# Successfully converted to json bytes
# Data for KEQU uploaded to S3: egdar_data/raw/2024-06-02/KEQU.json
# total companies uploaded: 400
# total tries: 447
# Successful CIK extraction for SEER
# Successfully converted to json bytes
# Data for SEER uploaded to S3: egdar_data/raw/2024-06-02/SEER.json
# total companies uploaded: 401
# total tries: 448
# Successful CIK extraction for IDR
# Successfully converted to json bytes
# Data for IDR uploaded to S3: egdar_data/raw/2024-06-02/IDR.json
# total companies uploaded: 402
# total tries: 449
# Successful CIK extraction for NXG
# HTTP error for NXG: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001506488.json
# total tries: 450
# Successful CIK extraction for TSE
# Successfully converted to json bytes
# Data for TSE uploaded to S3: egdar_data/raw/2024-06-02/TSE.json
# total companies uploaded: 403
# total tries: 451
# Successful CIK extraction for PHD
# HTTP error for PHD: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001305767.json
# total tries: 452
# Successful CIK extraction for OPRT
# Successfully converted to json bytes
# Data for OPRT uploaded to S3: egdar_data/raw/2024-06-02/OPRT.json
# total companies uploaded: 404
# total tries: 453
# Successful CIK extraction for CWGL
# Successfully converted to json bytes
# Data for CWGL uploaded to S3: egdar_data/raw/2024-06-02/CWGL.json
# total companies uploaded: 405
# total tries: 454
# Successful CIK extraction for OCCI
# HTTP error for OCCI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001716951.json
# total tries: 455
# Successful CIK extraction for RCFA
# Successfully converted to json bytes
# Data for RCFA uploaded to S3: egdar_data/raw/2024-06-02/RCFA.json
# total companies uploaded: 406
# total tries: 456
# Successful CIK extraction for ERDCF
# HTTP error for ERDCF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001398972.json
# total tries: 457
# Successful CIK extraction for MHGU
# HTTP error for MHGU: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000808219.json
# total tries: 458
# Successful CIK extraction for SGMO
# Successfully converted to json bytes
# Data for SGMO uploaded to S3: egdar_data/raw/2024-06-02/SGMO.json
# total companies uploaded: 407
# total tries: 459
# Successful CIK extraction for CBFV
# Successfully converted to json bytes
# Data for CBFV uploaded to S3: egdar_data/raw/2024-06-02/CBFV.json
# total companies uploaded: 408
# total tries: 460
# Successful CIK extraction for AJX
# Successfully converted to json bytes
# Data for AJX uploaded to S3: egdar_data/raw/2024-06-02/AJX.json
# total companies uploaded: 409
# total tries: 461
# Successful CIK extraction for EPSN
# Successfully converted to json bytes
# Data for EPSN uploaded to S3: egdar_data/raw/2024-06-02/EPSN.json
# total companies uploaded: 410
# total tries: 462
# Successful CIK extraction for WHG
# Successfully converted to json bytes
# Data for WHG uploaded to S3: egdar_data/raw/2024-06-02/WHG.json
# total companies uploaded: 411
# total tries: 463
# Successful CIK extraction for GIFI
# Successfully converted to json bytes
# Data for GIFI uploaded to S3: egdar_data/raw/2024-06-02/GIFI.json
# total companies uploaded: 412
# total tries: 464
# Successful CIK extraction for CBSTF
# Successfully converted to json bytes
# Data for CBSTF uploaded to S3: egdar_data/raw/2024-06-02/CBSTF.json
# total companies uploaded: 413
# total tries: 465
# Successful CIK extraction for HURC
# Successfully converted to json bytes
# Data for HURC uploaded to S3: egdar_data/raw/2024-06-02/HURC.json
# total companies uploaded: 414
# total tries: 466
# Successful CIK extraction for JHI
# Successfully converted to json bytes
# Data for JHI uploaded to S3: egdar_data/raw/2024-06-02/JHI.json
# total companies uploaded: 415
# total tries: 467
# Successful CIK extraction for ARC
# Successfully converted to json bytes
# Data for ARC uploaded to S3: egdar_data/raw/2024-06-02/ARC.json
# total companies uploaded: 416
# total tries: 468
# Successful CIK extraction for OVBC
# Successfully converted to json bytes
# Data for OVBC uploaded to S3: egdar_data/raw/2024-06-02/OVBC.json
# total companies uploaded: 417
# total tries: 469
# Successful CIK extraction for XNET
# Successfully converted to json bytes
# Data for XNET uploaded to S3: egdar_data/raw/2024-06-02/XNET.json
# total companies uploaded: 418
# total tries: 470
# Successful CIK extraction for ADAG
# Successfully converted to json bytes
# Data for ADAG uploaded to S3: egdar_data/raw/2024-06-02/ADAG.json
# total companies uploaded: 419
# total tries: 471
# Successful CIK extraction for SPPP
# Successfully converted to json bytes
# Data for SPPP uploaded to S3: egdar_data/raw/2024-06-02/SPPP.json
# total companies uploaded: 420
# total tries: 472
# Successful CIK extraction for AENT
# Successfully converted to json bytes
# Data for AENT uploaded to S3: egdar_data/raw/2024-06-02/AENT.json
# total companies uploaded: 421
# total tries: 473
# Successful CIK extraction for FRAF
# Successfully converted to json bytes
# Data for FRAF uploaded to S3: egdar_data/raw/2024-06-02/FRAF.json
# total companies uploaded: 422
# total tries: 474
# Successful CIK extraction for STG
# Successfully converted to json bytes
# Data for STG uploaded to S3: egdar_data/raw/2024-06-02/STG.json
# total companies uploaded: 423
# total tries: 475
# Successful CIK extraction for FGEN
# Successfully converted to json bytes
# Data for FGEN uploaded to S3: egdar_data/raw/2024-06-02/FGEN.json
# total companies uploaded: 424
# total tries: 476
# Successful CIK extraction for COYA
# Successfully converted to json bytes
# Data for COYA uploaded to S3: egdar_data/raw/2024-06-02/COYA.json
# total companies uploaded: 425
# total tries: 477
# Successful CIK extraction for PCF
# Successfully converted to json bytes
# Data for PCF uploaded to S3: egdar_data/raw/2024-06-02/PCF.json
# total companies uploaded: 426
# total tries: 478
# Successful CIK extraction for MYNA
# Successfully converted to json bytes
# Data for MYNA uploaded to S3: egdar_data/raw/2024-06-02/MYNA.json
# total companies uploaded: 427
# total tries: 479
# Successful CIK extraction for LIFE
# Successfully converted to json bytes
# Data for LIFE uploaded to S3: egdar_data/raw/2024-06-02/LIFE.json
# total companies uploaded: 428
# total tries: 480
# Successful CIK extraction for CCRD
# Successfully converted to json bytes
# Data for CCRD uploaded to S3: egdar_data/raw/2024-06-02/CCRD.json
# total companies uploaded: 429
# total tries: 481
# Successful CIK extraction for ALLK
# Successfully converted to json bytes
# Data for ALLK uploaded to S3: egdar_data/raw/2024-06-02/ALLK.json
# total companies uploaded: 430
# total tries: 482
# Successful CIK extraction for KF
# HTTP error for KF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000748691.json
# total tries: 483
# Successful CIK extraction for ESGH
# Successfully converted to json bytes
# Data for ESGH uploaded to S3: egdar_data/raw/2024-06-02/ESGH.json
# total companies uploaded: 431
# total tries: 484
# Successful CIK extraction for BYNO
# Successfully converted to json bytes
# Data for BYNO uploaded to S3: egdar_data/raw/2024-06-02/BYNO.json
# total companies uploaded: 432
# total tries: 485
# Successful CIK extraction for WW
# Successfully converted to json bytes
# Data for WW uploaded to S3: egdar_data/raw/2024-06-02/WW.json
# total companies uploaded: 433
# total tries: 486
# Successful CIK extraction for VOXR
# Successfully converted to json bytes
# Data for VOXR uploaded to S3: egdar_data/raw/2024-06-02/VOXR.json
# total companies uploaded: 434
# total tries: 487
# Successful CIK extraction for ARAT
# Successfully converted to json bytes
# Data for ARAT uploaded to S3: egdar_data/raw/2024-06-02/ARAT.json
# total companies uploaded: 435
# total tries: 488
# Successful CIK extraction for COOL
# Successfully converted to json bytes
# Data for COOL uploaded to S3: egdar_data/raw/2024-06-02/COOL.json
# total companies uploaded: 436
# total tries: 489
# Successful CIK extraction for FNCB
# Successfully converted to json bytes
# Data for FNCB uploaded to S3: egdar_data/raw/2024-06-02/FNCB.json
# total companies uploaded: 437
# total tries: 490
# Successful CIK extraction for CPHC
# Successfully converted to json bytes
# Data for CPHC uploaded to S3: egdar_data/raw/2024-06-02/CPHC.json
# total companies uploaded: 438
# total tries: 491
# Successful CIK extraction for ALTO
# Successfully converted to json bytes
# Data for ALTO uploaded to S3: egdar_data/raw/2024-06-02/ALTO.json
# total companies uploaded: 439
# total tries: 492
# Successful CIK extraction for APXI
# Successfully converted to json bytes
# Data for APXI uploaded to S3: egdar_data/raw/2024-06-02/APXI.json
# total companies uploaded: 440
# total tries: 493
# Successful CIK extraction for GSIW
# HTTP error for GSIW: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001954269.json
# total tries: 494
# Successful CIK extraction for CTXR
# Successfully converted to json bytes
# Data for CTXR uploaded to S3: egdar_data/raw/2024-06-02/CTXR.json
# total companies uploaded: 441
# total tries: 495
# Successful CIK extraction for POET
# Successfully converted to json bytes
# Data for POET uploaded to S3: egdar_data/raw/2024-06-02/POET.json
# total companies uploaded: 442
# total tries: 496
# Successful CIK extraction for CDAQ
# Successfully converted to json bytes
# Data for CDAQ uploaded to S3: egdar_data/raw/2024-06-02/CDAQ.json
# total companies uploaded: 443
# total tries: 497
# Successful CIK extraction for FSFG
# Successfully converted to json bytes
# Data for FSFG uploaded to S3: egdar_data/raw/2024-06-02/FSFG.json
# total companies uploaded: 444
# total tries: 498
# Successful CIK extraction for AMLX
# Successfully converted to json bytes
# Data for AMLX uploaded to S3: egdar_data/raw/2024-06-02/AMLX.json
# total companies uploaded: 445
# total tries: 499
# Successful CIK extraction for WMPN
# Successfully converted to json bytes
# Data for WMPN uploaded to S3: egdar_data/raw/2024-06-02/WMPN.json
# total companies uploaded: 446
# total tries: 500
# total companies uploaded: 446

# %%
tickers = list(sub_section_5['ticker'])

# Run the Ingestion Function
tickerJson_uploader(tickers, companyData, s3_bucket)
# Out:
# Successful CIK extraction for YIBO
# Successfully converted to json bytes
# Data for YIBO uploaded to S3: egdar_data/raw/2024-06-02/YIBO.json
# total companies uploaded: 1
# total tries: 1
# Successful CIK extraction for VIGL
# Successfully converted to json bytes
# Data for VIGL uploaded to S3: egdar_data/raw/2024-06-02/VIGL.json
# total companies uploaded: 2
# total tries: 2
# Successful CIK extraction for CFFS
# Successfully converted to json bytes
# Data for CFFS uploaded to S3: egdar_data/raw/2024-06-02/CFFS.json
# total companies uploaded: 3
# total tries: 3
# Successful CIK extraction for CSTAF
# Successfully converted to json bytes
# Data for CSTAF uploaded to S3: egdar_data/raw/2024-06-02/CSTAF.json
# total companies uploaded: 4
# total tries: 4
# Successful CIK extraction for ZTEK
# Successfully converted to json bytes
# Data for ZTEK uploaded to S3: egdar_data/raw/2024-06-02/ZTEK.json
# total companies uploaded: 5
# total tries: 5
# Successful CIK extraction for ASFH
# Successfully converted to json bytes
# Data for ASFH uploaded to S3: egdar_data/raw/2024-06-02/ASFH.json
# total companies uploaded: 6
# total tries: 6
# Successful CIK extraction for PFTA
# Successfully converted to json bytes
# Data for PFTA uploaded to S3: egdar_data/raw/2024-06-02/PFTA.json
# total companies uploaded: 7
# total tries: 7
# Successful CIK extraction for PAI
# HTTP error for PAI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000075398.json
# total tries: 8
# Successful CIK extraction for OMGA
# Successfully converted to json bytes
# Data for OMGA uploaded to S3: egdar_data/raw/2024-06-02/OMGA.json
# total companies uploaded: 8
# total tries: 9
# Successful CIK extraction for ISSC
# Successfully converted to json bytes
# Data for ISSC uploaded to S3: egdar_data/raw/2024-06-02/ISSC.json
# total companies uploaded: 9
# total tries: 10
# Successful CIK extraction for ESOA
# Successfully converted to json bytes
# Data for ESOA uploaded to S3: egdar_data/raw/2024-06-02/ESOA.json
# total companies uploaded: 10
# total tries: 11
# Successful CIK extraction for AKYA
# Successfully converted to json bytes
# Data for AKYA uploaded to S3: egdar_data/raw/2024-06-02/AKYA.json
# total companies uploaded: 11
# total tries: 12
# Successful CIK extraction for IAF
# HTTP error for IAF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000779336.json
# total tries: 13
# Successful CIK extraction for KPTI
# Successfully converted to json bytes
# Data for KPTI uploaded to S3: egdar_data/raw/2024-06-02/KPTI.json
# total companies uploaded: 12
# total tries: 14
# Successful CIK extraction for LUNA
# Successfully converted to json bytes
# Data for LUNA uploaded to S3: egdar_data/raw/2024-06-02/LUNA.json
# total companies uploaded: 13
# total tries: 15
# Successful CIK extraction for CXE
# HTTP error for CXE: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000845606.json
# total tries: 16
# Successful CIK extraction for OPTX
# Successfully converted to json bytes
# Data for OPTX uploaded to S3: egdar_data/raw/2024-06-02/OPTX.json
# total companies uploaded: 14
# total tries: 17
# Successful CIK extraction for ECF
# HTTP error for ECF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000793040.json
# total tries: 18
# Successful CIK extraction for ECBK
# Successfully converted to json bytes
# Data for ECBK uploaded to S3: egdar_data/raw/2024-06-02/ECBK.json
# total companies uploaded: 15
# total tries: 19
# Successful CIK extraction for BZFD
# Successfully converted to json bytes
# Data for BZFD uploaded to S3: egdar_data/raw/2024-06-02/BZFD.json
# total companies uploaded: 16
# total tries: 20
# Successful CIK extraction for CCFN
# Successfully converted to json bytes
# Data for CCFN uploaded to S3: egdar_data/raw/2024-06-02/CCFN.json
# total companies uploaded: 17
# total tries: 21
# Successful CIK extraction for CAAS
# Successfully converted to json bytes
# Data for CAAS uploaded to S3: egdar_data/raw/2024-06-02/CAAS.json
# total companies uploaded: 18
# total tries: 22
# Successful CIK extraction for AFBI
# Successfully converted to json bytes
# Data for AFBI uploaded to S3: egdar_data/raw/2024-06-02/AFBI.json
# total companies uploaded: 19
# total tries: 23
# Successful CIK extraction for VTSI
# Successfully converted to json bytes
# Data for VTSI uploaded to S3: egdar_data/raw/2024-06-02/VTSI.json
# total companies uploaded: 20
# total tries: 24
# Successful CIK extraction for SGA
# Successfully converted to json bytes
# Data for SGA uploaded to S3: egdar_data/raw/2024-06-02/SGA.json
# total companies uploaded: 21
# total tries: 25
# Successful CIK extraction for IMUX
# Successfully converted to json bytes
# Data for IMUX uploaded to S3: egdar_data/raw/2024-06-02/IMUX.json
# total companies uploaded: 22
# total tries: 26
# Successful CIK extraction for PNST
# Successfully converted to json bytes
# Data for PNST uploaded to S3: egdar_data/raw/2024-06-02/PNST.json
# total companies uploaded: 23
# total tries: 27
# Successful CIK extraction for BROG
# Successfully converted to json bytes
# Data for BROG uploaded to S3: egdar_data/raw/2024-06-02/BROG.json
# total companies uploaded: 24
# total tries: 28
# Successful CIK extraction for DMAC
# Successfully converted to json bytes
# Data for DMAC uploaded to S3: egdar_data/raw/2024-06-02/DMAC.json
# total companies uploaded: 25
# total tries: 29
# Successful CIK extraction for PDSB
# Successfully converted to json bytes
# Data for PDSB uploaded to S3: egdar_data/raw/2024-06-02/PDSB.json
# total companies uploaded: 26
# total tries: 30
# Successful CIK extraction for NIM
# HTTP error for NIM: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000890119.json
# total tries: 31
# Successful CIK extraction for SKLZ
# Successfully converted to json bytes
# Data for SKLZ uploaded to S3: egdar_data/raw/2024-06-02/SKLZ.json
# total companies uploaded: 27
# total tries: 32
# Successful CIK extraction for TLGY
# Successfully converted to json bytes
# Data for TLGY uploaded to S3: egdar_data/raw/2024-06-02/TLGY.json
# total companies uploaded: 28
# total tries: 33
# Successful CIK extraction for MRBK
# Successfully converted to json bytes
# Data for MRBK uploaded to S3: egdar_data/raw/2024-06-02/MRBK.json
# total companies uploaded: 29
# total tries: 34
# Successful CIK extraction for FTK
# Successfully converted to json bytes
# Data for FTK uploaded to S3: egdar_data/raw/2024-06-02/FTK.json
# total companies uploaded: 30
# total tries: 35
# Successful CIK extraction for CHMI
# Successfully converted to json bytes
# Data for CHMI uploaded to S3: egdar_data/raw/2024-06-02/CHMI.json
# total companies uploaded: 31
# total tries: 36
# Successful CIK extraction for DTC
# Successfully converted to json bytes
# Data for DTC uploaded to S3: egdar_data/raw/2024-06-02/DTC.json
# total companies uploaded: 32
# total tries: 37
# Successful CIK extraction for CHN
# HTTP error for CHN: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000845379.json
# total tries: 38
# Successful CIK extraction for NOBH
# Successfully converted to json bytes
# Data for NOBH uploaded to S3: egdar_data/raw/2024-06-02/NOBH.json
# total companies uploaded: 33
# total tries: 39
# Successful CIK extraction for VTGN
# Successfully converted to json bytes
# Data for VTGN uploaded to S3: egdar_data/raw/2024-06-02/VTGN.json
# total companies uploaded: 34
# total tries: 40
# Successful CIK extraction for BYSI
# Successfully converted to json bytes
# Data for BYSI uploaded to S3: egdar_data/raw/2024-06-02/BYSI.json
# total companies uploaded: 35
# total tries: 41
# Successful CIK extraction for VERI
# Successfully converted to json bytes
# Data for VERI uploaded to S3: egdar_data/raw/2024-06-02/VERI.json
# total companies uploaded: 36
# total tries: 42
# Successful CIK extraction for SATL
# Successfully converted to json bytes
# Data for SATL uploaded to S3: egdar_data/raw/2024-06-02/SATL.json
# total companies uploaded: 37
# total tries: 43
# Successful CIK extraction for SBI
# HTTP error for SBI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000882300.json
# total tries: 44
# Successful CIK extraction for PFO
# HTTP error for PFO: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000882071.json
# total tries: 45
# Successful CIK extraction for CRGO
# Successfully converted to json bytes
# Data for CRGO uploaded to S3: egdar_data/raw/2024-06-02/CRGO.json
# total companies uploaded: 38
# total tries: 46
# Successful CIK extraction for THCP
# Successfully converted to json bytes
# Data for THCP uploaded to S3: egdar_data/raw/2024-06-02/THCP.json
# total companies uploaded: 39
# total tries: 47
# Successful CIK extraction for NAAS
# Successfully converted to json bytes
# Data for NAAS uploaded to S3: egdar_data/raw/2024-06-02/NAAS.json
# total companies uploaded: 40
# total tries: 48
# Successful CIK extraction for CCG
# Successfully converted to json bytes
# Data for CCG uploaded to S3: egdar_data/raw/2024-06-02/CCG.json
# total companies uploaded: 41
# total tries: 49
# Successful CIK extraction for FNWD
# Successfully converted to json bytes
# Data for FNWD uploaded to S3: egdar_data/raw/2024-06-02/FNWD.json
# total companies uploaded: 42
# total tries: 50
# Successful CIK extraction for MCAC
# Successfully converted to json bytes
# Data for MCAC uploaded to S3: egdar_data/raw/2024-06-02/MCAC.json
# total companies uploaded: 43
# total tries: 51
# Successful CIK extraction for VTNR
# Successfully converted to json bytes
# Data for VTNR uploaded to S3: egdar_data/raw/2024-06-02/VTNR.json
# total companies uploaded: 44
# total tries: 52
# Successful CIK extraction for EBMT
# Successfully converted to json bytes
# Data for EBMT uploaded to S3: egdar_data/raw/2024-06-02/EBMT.json
# total companies uploaded: 45
# total tries: 53
# Successful CIK extraction for GAIA
# Successfully converted to json bytes
# Data for GAIA uploaded to S3: egdar_data/raw/2024-06-02/GAIA.json
# total companies uploaded: 46
# total tries: 54
# Successful CIK extraction for CSLM
# Successfully converted to json bytes
# Data for CSLM uploaded to S3: egdar_data/raw/2024-06-02/CSLM.json
# total companies uploaded: 47
# total tries: 55
# Successful CIK extraction for EFSI
# Successfully converted to json bytes
# Data for EFSI uploaded to S3: egdar_data/raw/2024-06-02/EFSI.json
# total companies uploaded: 48
# total tries: 56
# Successful CIK extraction for CHAA
# Successfully converted to json bytes
# Data for CHAA uploaded to S3: egdar_data/raw/2024-06-02/CHAA.json
# total companies uploaded: 49
# total tries: 57
# Successful CIK extraction for UNB
# Successfully converted to json bytes
# Data for UNB uploaded to S3: egdar_data/raw/2024-06-02/UNB.json
# total companies uploaded: 50
# total tries: 58
# Successful CIK extraction for BLUA
# Successfully converted to json bytes
# Data for BLUA uploaded to S3: egdar_data/raw/2024-06-02/BLUA.json
# total companies uploaded: 51
# total tries: 59
# Successful CIK extraction for STRT
# Successfully converted to json bytes
# Data for STRT uploaded to S3: egdar_data/raw/2024-06-02/STRT.json
# total companies uploaded: 52
# total tries: 60
# Successful CIK extraction for CLRB
# Successfully converted to json bytes
# Data for CLRB uploaded to S3: egdar_data/raw/2024-06-02/CLRB.json
# total companies uploaded: 53
# total tries: 61
# Successful CIK extraction for YI
# Successfully converted to json bytes
# Data for YI uploaded to S3: egdar_data/raw/2024-06-02/YI.json
# total companies uploaded: 54
# total tries: 62
# Successful CIK extraction for ACNT
# Successfully converted to json bytes
# Data for ACNT uploaded to S3: egdar_data/raw/2024-06-02/ACNT.json
# total companies uploaded: 55
# total tries: 63
# Successful CIK extraction for MVO
# HTTP error for MVO: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001371782.json
# total tries: 64
# Successful CIK extraction for TGAA
# Successfully converted to json bytes
# Data for TGAA uploaded to S3: egdar_data/raw/2024-06-02/TGAA.json
# total companies uploaded: 56
# total tries: 65
# Successful CIK extraction for GPAC
# Successfully converted to json bytes
# Data for GPAC uploaded to S3: egdar_data/raw/2024-06-02/GPAC.json
# total companies uploaded: 57
# total tries: 66
# Successful CIK extraction for BEEP
# Successfully converted to json bytes
# Data for BEEP uploaded to S3: egdar_data/raw/2024-06-02/BEEP.json
# total companies uploaded: 58
# total tries: 67
# Successful CIK extraction for LARK
# Successfully converted to json bytes
# Data for LARK uploaded to S3: egdar_data/raw/2024-06-02/LARK.json
# total companies uploaded: 59
# total tries: 68
# Successful CIK extraction for MPAA
# Successfully converted to json bytes
# Data for MPAA uploaded to S3: egdar_data/raw/2024-06-02/MPAA.json
# total companies uploaded: 60
# total tries: 69
# Successful CIK extraction for PSQH
# Successfully converted to json bytes
# Data for PSQH uploaded to S3: egdar_data/raw/2024-06-02/PSQH.json
# total companies uploaded: 61
# total tries: 70
# Successful CIK extraction for KSM
# HTTP error for KSM: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000846596.json
# total tries: 71
# Successful CIK extraction for SY
# Successfully converted to json bytes
# Data for SY uploaded to S3: egdar_data/raw/2024-06-02/SY.json
# total companies uploaded: 62
# total tries: 72
# Successful CIK extraction for INVE
# Successfully converted to json bytes
# Data for INVE uploaded to S3: egdar_data/raw/2024-06-02/INVE.json
# total companies uploaded: 63
# total tries: 73
# Successful CIK extraction for AXR
# Successfully converted to json bytes
# Data for AXR uploaded to S3: egdar_data/raw/2024-06-02/AXR.json
# total companies uploaded: 64
# total tries: 74
# Successful CIK extraction for IH
# Successfully converted to json bytes
# Data for IH uploaded to S3: egdar_data/raw/2024-06-02/IH.json
# total companies uploaded: 65
# total tries: 75
# Successful CIK extraction for HCIL
# Successfully converted to json bytes
# Data for HCIL uploaded to S3: egdar_data/raw/2024-06-02/HCIL.json
# total companies uploaded: 66
# total tries: 76
# Successful CIK extraction for MPIR
# HTTP error for MPIR: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000815577.json
# total tries: 77
# Successful CIK extraction for CSBB
# Successfully converted to json bytes
# Data for CSBB uploaded to S3: egdar_data/raw/2024-06-02/CSBB.json
# total companies uploaded: 67
# total tries: 78
# Successful CIK extraction for FNWB
# Successfully converted to json bytes
# Data for FNWB uploaded to S3: egdar_data/raw/2024-06-02/FNWB.json
# total companies uploaded: 68
# total tries: 79
# Successful CIK extraction for PNRLF
# Successfully converted to json bytes
# Data for PNRLF uploaded to S3: egdar_data/raw/2024-06-02/PNRLF.json
# total companies uploaded: 69
# total tries: 80
# Successful CIK extraction for SWZ
# HTTP error for SWZ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000813623.json
# total tries: 81
# Successful CIK extraction for CNF
# Successfully converted to json bytes
# Data for CNF uploaded to S3: egdar_data/raw/2024-06-02/CNF.json
# total companies uploaded: 70
# total tries: 82
# Successful CIK extraction for SSNT
# Successfully converted to json bytes
# Data for SSNT uploaded to S3: egdar_data/raw/2024-06-02/SSNT.json
# total companies uploaded: 71
# total tries: 83
# Successful CIK extraction for CGO
# HTTP error for CGO: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001285650.json
# total tries: 84
# Successful CIK extraction for PCM
# HTTP error for PCM: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000908187.json
# total tries: 85
# Successful CIK extraction for YTRA
# Successfully converted to json bytes
# Data for YTRA uploaded to S3: egdar_data/raw/2024-06-02/YTRA.json
# total companies uploaded: 72
# total tries: 86
# Successful CIK extraction for ACR
# Successfully converted to json bytes
# Data for ACR uploaded to S3: egdar_data/raw/2024-06-02/ACR.json
# total companies uploaded: 73
# total tries: 87
# Successful CIK extraction for PWUP
# Successfully converted to json bytes
# Data for PWUP uploaded to S3: egdar_data/raw/2024-06-02/PWUP.json
# total companies uploaded: 74
# total tries: 88
# Successful CIK extraction for DOUG
# Successfully converted to json bytes
# Data for DOUG uploaded to S3: egdar_data/raw/2024-06-02/DOUG.json
# total companies uploaded: 75
# total tries: 89
# Successful CIK extraction for SUP
# Successfully converted to json bytes
# Data for SUP uploaded to S3: egdar_data/raw/2024-06-02/SUP.json
# total companies uploaded: 76
# total tries: 90
# Successful CIK extraction for CLSD
# Successfully converted to json bytes
# Data for CLSD uploaded to S3: egdar_data/raw/2024-06-02/CLSD.json
# total companies uploaded: 77
# total tries: 91
# Successful CIK extraction for RRGB
# Successfully converted to json bytes
# Data for RRGB uploaded to S3: egdar_data/raw/2024-06-02/RRGB.json
# total companies uploaded: 78
# total tries: 92
# Successful CIK extraction for MPTI
# Successfully converted to json bytes
# Data for MPTI uploaded to S3: egdar_data/raw/2024-06-02/MPTI.json
# total companies uploaded: 79
# total tries: 93
# Successful CIK extraction for SFBC
# Successfully converted to json bytes
# Data for SFBC uploaded to S3: egdar_data/raw/2024-06-02/SFBC.json
# total companies uploaded: 80
# total tries: 94
# Successful CIK extraction for VSTM
# Successfully converted to json bytes
# Data for VSTM uploaded to S3: egdar_data/raw/2024-06-02/VSTM.json
# total companies uploaded: 81
# total tries: 95
# Successful CIK extraction for BKKT
# Successfully converted to json bytes
# Data for BKKT uploaded to S3: egdar_data/raw/2024-06-02/BKKT.json
# total companies uploaded: 82
# total tries: 96
# Successful CIK extraction for AOUT
# Successfully converted to json bytes
# Data for AOUT uploaded to S3: egdar_data/raw/2024-06-02/AOUT.json
# total companies uploaded: 83
# total tries: 97
# Successful CIK extraction for YCQH
# Successfully converted to json bytes
# Data for YCQH uploaded to S3: egdar_data/raw/2024-06-02/YCQH.json
# total companies uploaded: 84
# total tries: 98
# Successful CIK extraction for FCAP
# Successfully converted to json bytes
# Data for FCAP uploaded to S3: egdar_data/raw/2024-06-02/FCAP.json
# total companies uploaded: 85
# total tries: 99
# Successful CIK extraction for MVST
# Successfully converted to json bytes
# Data for MVST uploaded to S3: egdar_data/raw/2024-06-02/MVST.json
# total companies uploaded: 86
# total tries: 100
# Successful CIK extraction for LVPA
# Successfully converted to json bytes
# Data for LVPA uploaded to S3: egdar_data/raw/2024-06-02/LVPA.json
# total companies uploaded: 87
# total tries: 101
# Successful CIK extraction for SOL
# Successfully converted to json bytes
# Data for SOL uploaded to S3: egdar_data/raw/2024-06-02/SOL.json
# total companies uploaded: 88
# total tries: 102
# Successful CIK extraction for EMYB
# Successfully converted to json bytes
# Data for EMYB uploaded to S3: egdar_data/raw/2024-06-02/EMYB.json
# total companies uploaded: 89
# total tries: 103
# Successful CIK extraction for DHX
# Successfully converted to json bytes
# Data for DHX uploaded to S3: egdar_data/raw/2024-06-02/DHX.json
# total companies uploaded: 90
# total tries: 104
# Successful CIK extraction for KVHI
# Successfully converted to json bytes
# Data for KVHI uploaded to S3: egdar_data/raw/2024-06-02/KVHI.json
# total companies uploaded: 91
# total tries: 105
# Successful CIK extraction for BW
# Successfully converted to json bytes
# Data for BW uploaded to S3: egdar_data/raw/2024-06-02/BW.json
# total companies uploaded: 92
# total tries: 106
# Successful CIK extraction for INSG
# Successfully converted to json bytes
# Data for INSG uploaded to S3: egdar_data/raw/2024-06-02/INSG.json
# total companies uploaded: 93
# total tries: 107
# Successful CIK extraction for VUZI
# Successfully converted to json bytes
# Data for VUZI uploaded to S3: egdar_data/raw/2024-06-02/VUZI.json
# total companies uploaded: 94
# total tries: 108
# Successful CIK extraction for LGYV
# Successfully converted to json bytes
# Data for LGYV uploaded to S3: egdar_data/raw/2024-06-02/LGYV.json
# total companies uploaded: 95
# total tries: 109
# Successful CIK extraction for FEAM
# Successfully converted to json bytes
# Data for FEAM uploaded to S3: egdar_data/raw/2024-06-02/FEAM.json
# total companies uploaded: 96
# total tries: 110
# Successful CIK extraction for EVF
# Successfully converted to json bytes
# Data for EVF uploaded to S3: egdar_data/raw/2024-06-02/EVF.json
# total companies uploaded: 97
# total tries: 111
# Successful CIK extraction for TZOO
# Successfully converted to json bytes
# Data for TZOO uploaded to S3: egdar_data/raw/2024-06-02/TZOO.json
# total companies uploaded: 98
# total tries: 112
# Successful CIK extraction for EPRX
# Successfully converted to json bytes
# Data for EPRX uploaded to S3: egdar_data/raw/2024-06-02/EPRX.json
# total companies uploaded: 99
# total tries: 113
# Successful CIK extraction for IVAC
# Successfully converted to json bytes
# Data for IVAC uploaded to S3: egdar_data/raw/2024-06-02/IVAC.json
# total companies uploaded: 100
# total tries: 114
# Successful CIK extraction for MYO
# Successfully converted to json bytes
# Data for MYO uploaded to S3: egdar_data/raw/2024-06-02/MYO.json
# total companies uploaded: 101
# total tries: 115
# Successful CIK extraction for RSTN
# Successfully converted to json bytes
# Data for RSTN uploaded to S3: egdar_data/raw/2024-06-02/RSTN.json
# total companies uploaded: 102
# total tries: 116
# Successful CIK extraction for RMI
# Successfully converted to json bytes
# Data for RMI uploaded to S3: egdar_data/raw/2024-06-02/RMI.json
# total companies uploaded: 103
# total tries: 117
# Successful CIK extraction for SILC
# Successfully converted to json bytes
# Data for SILC uploaded to S3: egdar_data/raw/2024-06-02/SILC.json
# total companies uploaded: 104
# total tries: 118
# Successful CIK extraction for FONR
# Successfully converted to json bytes
# Data for FONR uploaded to S3: egdar_data/raw/2024-06-02/FONR.json
# total companies uploaded: 105
# total tries: 119
# Successful CIK extraction for FFMGF
# Successfully converted to json bytes
# Data for FFMGF uploaded to S3: egdar_data/raw/2024-06-02/FFMGF.json
# total companies uploaded: 106
# total tries: 120
# Successful CIK extraction for LIFW
# Successfully converted to json bytes
# Data for LIFW uploaded to S3: egdar_data/raw/2024-06-02/LIFW.json
# total companies uploaded: 107
# total tries: 121
# Successful CIK extraction for ELVA
# Successfully converted to json bytes
# Data for ELVA uploaded to S3: egdar_data/raw/2024-06-02/ELVA.json
# total companies uploaded: 108
# total tries: 122
# Successful CIK extraction for MGF
# HTTP error for MGF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000811922.json
# total tries: 123
# Successful CIK extraction for HMNF
# Successfully converted to json bytes
# Data for HMNF uploaded to S3: egdar_data/raw/2024-06-02/HMNF.json
# total companies uploaded: 109
# total tries: 124
# Successful CIK extraction for FXNC
# Successfully converted to json bytes
# Data for FXNC uploaded to S3: egdar_data/raw/2024-06-02/FXNC.json
# total companies uploaded: 110
# total tries: 125
# Successful CIK extraction for BWAY
# Successfully converted to json bytes
# Data for BWAY uploaded to S3: egdar_data/raw/2024-06-02/BWAY.json
# total companies uploaded: 111
# total tries: 126
# Successful CIK extraction for PSIX
# Successfully converted to json bytes
# Data for PSIX uploaded to S3: egdar_data/raw/2024-06-02/PSIX.json
# total companies uploaded: 112
# total tries: 127
# Successful CIK extraction for NMT
# HTTP error for NMT: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000897419.json
# total tries: 128
# Successful CIK extraction for OPI
# Successfully converted to json bytes
# Data for OPI uploaded to S3: egdar_data/raw/2024-06-02/OPI.json
# total companies uploaded: 113
# total tries: 129
# Successful CIK extraction for ARMP
# Successfully converted to json bytes
# Data for ARMP uploaded to S3: egdar_data/raw/2024-06-02/ARMP.json
# total companies uploaded: 114
# total tries: 130
# Successful CIK extraction for LFVN
# Successfully converted to json bytes
# Data for LFVN uploaded to S3: egdar_data/raw/2024-06-02/LFVN.json
# total companies uploaded: 115
# total tries: 131
# Successful CIK extraction for IXAQ
# Successfully converted to json bytes
# Data for IXAQ uploaded to S3: egdar_data/raw/2024-06-02/IXAQ.json
# total companies uploaded: 116
# total tries: 132
# Successful CIK extraction for BIG
# Successfully converted to json bytes
# Data for BIG uploaded to S3: egdar_data/raw/2024-06-02/BIG.json
# total companies uploaded: 117
# total tries: 133
# Successful CIK extraction for PRPH
# Successfully converted to json bytes
# Data for PRPH uploaded to S3: egdar_data/raw/2024-06-02/PRPH.json
# total companies uploaded: 118
# total tries: 134
# Successful CIK extraction for TBMC
# Successfully converted to json bytes
# Data for TBMC uploaded to S3: egdar_data/raw/2024-06-02/TBMC.json
# total companies uploaded: 119
# total tries: 135
# Successful CIK extraction for GECC
# Successfully converted to json bytes
# Data for GECC uploaded to S3: egdar_data/raw/2024-06-02/GECC.json
# total companies uploaded: 120
# total tries: 136
# Successful CIK extraction for KRMD
# Successfully converted to json bytes
# Data for KRMD uploaded to S3: egdar_data/raw/2024-06-02/KRMD.json
# total companies uploaded: 121
# total tries: 137
# Successful CIK extraction for XTNT
# Successfully converted to json bytes
# Data for XTNT uploaded to S3: egdar_data/raw/2024-06-02/XTNT.json
# total companies uploaded: 122
# total tries: 138
# Successful CIK extraction for BMBN
# HTTP error for BMBN: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000804563.json
# total tries: 139
# Successful CIK extraction for RFM
# Successfully converted to json bytes
# Data for RFM uploaded to S3: egdar_data/raw/2024-06-02/RFM.json
# total companies uploaded: 123
# total tries: 140
# Successful CIK extraction for AREC
# Successfully converted to json bytes
# Data for AREC uploaded to S3: egdar_data/raw/2024-06-02/AREC.json
# total companies uploaded: 124
# total tries: 141
# Successful CIK extraction for BOWN
# Successfully converted to json bytes
# Data for BOWN uploaded to S3: egdar_data/raw/2024-06-02/BOWN.json
# total companies uploaded: 125
# total tries: 142
# Successful CIK extraction for SBFG
# Successfully converted to json bytes
# Data for SBFG uploaded to S3: egdar_data/raw/2024-06-02/SBFG.json
# total companies uploaded: 126
# total tries: 143
# Successful CIK extraction for WPRT
# Successfully converted to json bytes
# Data for WPRT uploaded to S3: egdar_data/raw/2024-06-02/WPRT.json
# total companies uploaded: 127
# total tries: 144
# Successful CIK extraction for HNW
# HTTP error for HNW: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001388126.json
# total tries: 145
# Successful CIK extraction for BFGX
# Successfully converted to json bytes
# Data for BFGX uploaded to S3: egdar_data/raw/2024-06-02/BFGX.json
# total companies uploaded: 128
# total tries: 146
# Successful CIK extraction for GGZ
# Successfully converted to json bytes
# Data for GGZ uploaded to S3: egdar_data/raw/2024-06-02/GGZ.json
# total companies uploaded: 129
# total tries: 147
# Successful CIK extraction for BATL
# Successfully converted to json bytes
# Data for BATL uploaded to S3: egdar_data/raw/2024-06-02/BATL.json
# total companies uploaded: 130
# total tries: 148
# Successful CIK extraction for IHD
# HTTP error for IHD: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001496292.json
# total tries: 149
# Successful CIK extraction for UTGN
# Successfully converted to json bytes
# Data for UTGN uploaded to S3: egdar_data/raw/2024-06-02/UTGN.json
# total companies uploaded: 131
# total tries: 150
# Successful CIK extraction for ATHA
# Successfully converted to json bytes
# Data for ATHA uploaded to S3: egdar_data/raw/2024-06-02/ATHA.json
# total companies uploaded: 132
# total tries: 151
# Successful CIK extraction for GSVRF
# HTTP error for GSVRF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000865400.json
# total tries: 152
# Successful CIK extraction for SSSS
# Successfully converted to json bytes
# Data for SSSS uploaded to S3: egdar_data/raw/2024-06-02/SSSS.json
# total companies uploaded: 133
# total tries: 153
# Successful CIK extraction for PMVP
# Successfully converted to json bytes
# Data for PMVP uploaded to S3: egdar_data/raw/2024-06-02/PMVP.json
# total companies uploaded: 134
# total tries: 154
# Successful CIK extraction for DSAQ
# Successfully converted to json bytes
# Data for DSAQ uploaded to S3: egdar_data/raw/2024-06-02/DSAQ.json
# total companies uploaded: 135
# total tries: 155
# Successful CIK extraction for CDIX
# Successfully converted to json bytes
# Data for CDIX uploaded to S3: egdar_data/raw/2024-06-02/CDIX.json
# total companies uploaded: 136
# total tries: 156
# Successful CIK extraction for OMEX
# Successfully converted to json bytes
# Data for OMEX uploaded to S3: egdar_data/raw/2024-06-02/OMEX.json
# total companies uploaded: 137
# total tries: 157
# Successful CIK extraction for JLS
# HTTP error for JLS: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001472215.json
# total tries: 158
# Successful CIK extraction for BCOV
# Successfully converted to json bytes
# Data for BCOV uploaded to S3: egdar_data/raw/2024-06-02/BCOV.json
# total companies uploaded: 138
# total tries: 159
# Successful CIK extraction for MRT
# Successfully converted to json bytes
# Data for MRT uploaded to S3: egdar_data/raw/2024-06-02/MRT.json
# total companies uploaded: 139
# total tries: 160
# Successful CIK extraction for SNCR
# Successfully converted to json bytes
# Data for SNCR uploaded to S3: egdar_data/raw/2024-06-02/SNCR.json
# total companies uploaded: 140
# total tries: 161
# Successful CIK extraction for SND
# Successfully converted to json bytes
# Data for SND uploaded to S3: egdar_data/raw/2024-06-02/SND.json
# total companies uploaded: 141
# total tries: 162
# Successful CIK extraction for ETON
# Successfully converted to json bytes
# Data for ETON uploaded to S3: egdar_data/raw/2024-06-02/ETON.json
# total companies uploaded: 142
# total tries: 163
# Successful CIK extraction for MAIA
# Successfully converted to json bytes
# Data for MAIA uploaded to S3: egdar_data/raw/2024-06-02/MAIA.json
# total companies uploaded: 143
# total tries: 164
# Successful CIK extraction for KOPN
# Successfully converted to json bytes
# Data for KOPN uploaded to S3: egdar_data/raw/2024-06-02/KOPN.json
# total companies uploaded: 144
# total tries: 165
# Successful CIK extraction for VOR
# Successfully converted to json bytes
# Data for VOR uploaded to S3: egdar_data/raw/2024-06-02/VOR.json
# total companies uploaded: 145
# total tries: 166
# Successful CIK extraction for GDL
# Successfully converted to json bytes
# Data for GDL uploaded to S3: egdar_data/raw/2024-06-02/GDL.json
# total companies uploaded: 146
# total tries: 167
# Successful CIK extraction for YBGJ
# Successfully converted to json bytes
# Data for YBGJ uploaded to S3: egdar_data/raw/2024-06-02/YBGJ.json
# total companies uploaded: 147
# total tries: 168
# Successful CIK extraction for SRTS
# Successfully converted to json bytes
# Data for SRTS uploaded to S3: egdar_data/raw/2024-06-02/SRTS.json
# total companies uploaded: 148
# total tries: 169
# Successful CIK extraction for DIT
# Successfully converted to json bytes
# Data for DIT uploaded to S3: egdar_data/raw/2024-06-02/DIT.json
# total companies uploaded: 149
# total tries: 170
# Successful CIK extraction for CCIF
# Successfully converted to json bytes
# Data for CCIF uploaded to S3: egdar_data/raw/2024-06-02/CCIF.json
# total companies uploaded: 150
# total tries: 171
# Successful CIK extraction for AFJK
# Successfully converted to json bytes
# Data for AFJK uploaded to S3: egdar_data/raw/2024-06-02/AFJK.json
# total companies uploaded: 151
# total tries: 172
# Successful CIK extraction for WTRV
# Successfully converted to json bytes
# Data for WTRV uploaded to S3: egdar_data/raw/2024-06-02/WTRV.json
# total companies uploaded: 152
# total tries: 173
# Successful CIK extraction for MAYS
# Successfully converted to json bytes
# Data for MAYS uploaded to S3: egdar_data/raw/2024-06-02/MAYS.json
# total companies uploaded: 153
# total tries: 174
# Successful CIK extraction for ZHYBF
# Successfully converted to json bytes
# Data for ZHYBF uploaded to S3: egdar_data/raw/2024-06-02/ZHYBF.json
# total companies uploaded: 154
# total tries: 175
# Successful CIK extraction for TLSA
# Successfully converted to json bytes
# Data for TLSA uploaded to S3: egdar_data/raw/2024-06-02/TLSA.json
# total companies uploaded: 155
# total tries: 176
# Successful CIK extraction for CMBM
# Successfully converted to json bytes
# Data for CMBM uploaded to S3: egdar_data/raw/2024-06-02/CMBM.json
# total companies uploaded: 156
# total tries: 177
# Successful CIK extraction for NMI
# HTTP error for NMI: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000830271.json
# total tries: 178
# Successful CIK extraction for QETA
# Successfully converted to json bytes
# Data for QETA uploaded to S3: egdar_data/raw/2024-06-02/QETA.json
# total companies uploaded: 157
# total tries: 179
# Successful CIK extraction for GLAC
# Successfully converted to json bytes
# Data for GLAC uploaded to S3: egdar_data/raw/2024-06-02/GLAC.json
# total companies uploaded: 158
# total tries: 180
# Successful CIK extraction for INAQ
# Successfully converted to json bytes
# Data for INAQ uploaded to S3: egdar_data/raw/2024-06-02/INAQ.json
# total companies uploaded: 159
# total tries: 181
# Successful CIK extraction for BRID
# Successfully converted to json bytes
# Data for BRID uploaded to S3: egdar_data/raw/2024-06-02/BRID.json
# total companies uploaded: 160
# total tries: 182
# Successful CIK extraction for BSBK
# Successfully converted to json bytes
# Data for BSBK uploaded to S3: egdar_data/raw/2024-06-02/BSBK.json
# total companies uploaded: 161
# total tries: 183
# Successful CIK extraction for FAT
# Successfully converted to json bytes
# Data for FAT uploaded to S3: egdar_data/raw/2024-06-02/FAT.json
# total companies uploaded: 162
# total tries: 184
# Successful CIK extraction for GDNSF
# Successfully converted to json bytes
# Data for GDNSF uploaded to S3: egdar_data/raw/2024-06-02/GDNSF.json
# total companies uploaded: 163
# total tries: 185
# Successful CIK extraction for MFH
# Successfully converted to json bytes
# Data for MFH uploaded to S3: egdar_data/raw/2024-06-02/MFH.json
# total companies uploaded: 164
# total tries: 186
# Successful CIK extraction for DYCQ
# Successfully converted to json bytes
# Data for DYCQ uploaded to S3: egdar_data/raw/2024-06-02/DYCQ.json
# total companies uploaded: 165
# total tries: 187
# Successful CIK extraction for ASRT
# Successfully converted to json bytes
# Data for ASRT uploaded to S3: egdar_data/raw/2024-06-02/ASRT.json
# total companies uploaded: 166
# total tries: 188
# Successful CIK extraction for BCV
# Successfully converted to json bytes
# Data for BCV uploaded to S3: egdar_data/raw/2024-06-02/BCV.json
# total companies uploaded: 167
# total tries: 189
# Successful CIK extraction for TOP
# Successfully converted to json bytes
# Data for TOP uploaded to S3: egdar_data/raw/2024-06-02/TOP.json
# total companies uploaded: 168
# total tries: 190
# Successful CIK extraction for VCSA
# Successfully converted to json bytes
# Data for VCSA uploaded to S3: egdar_data/raw/2024-06-02/VCSA.json
# total companies uploaded: 169
# total tries: 191
# Successful CIK extraction for CNTB
# Successfully converted to json bytes
# Data for CNTB uploaded to S3: egdar_data/raw/2024-06-02/CNTB.json
# total companies uploaded: 170
# total tries: 192
# Successful CIK extraction for BEEM
# Successfully converted to json bytes
# Data for BEEM uploaded to S3: egdar_data/raw/2024-06-02/BEEM.json
# total companies uploaded: 171
# total tries: 193
# Successful CIK extraction for ACAB
# Successfully converted to json bytes
# Data for ACAB uploaded to S3: egdar_data/raw/2024-06-02/ACAB.json
# total companies uploaded: 172
# total tries: 194
# Successful CIK extraction for BKHA
# Successfully converted to json bytes
# Data for BKHA uploaded to S3: egdar_data/raw/2024-06-02/BKHA.json
# total companies uploaded: 173
# total tries: 195
# Successful CIK extraction for ERH
# HTTP error for ERH: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001279014.json
# total tries: 196
# Successful CIK extraction for BLGO
# Successfully converted to json bytes
# Data for BLGO uploaded to S3: egdar_data/raw/2024-06-02/BLGO.json
# total companies uploaded: 174
# total tries: 197
# Successful CIK extraction for PFX
# Successfully converted to json bytes
# Data for PFX uploaded to S3: egdar_data/raw/2024-06-02/PFX.json
# total companies uploaded: 175
# total tries: 198
# Successful CIK extraction for VANI
# Successfully converted to json bytes
# Data for VANI uploaded to S3: egdar_data/raw/2024-06-02/VANI.json
# total companies uploaded: 176
# total tries: 199
# Successful CIK extraction for SKYX
# Successfully converted to json bytes
# Data for SKYX uploaded to S3: egdar_data/raw/2024-06-02/SKYX.json
# total companies uploaded: 177
# total tries: 200
# Successful CIK extraction for CXDO
# Successfully converted to json bytes
# Data for CXDO uploaded to S3: egdar_data/raw/2024-06-02/CXDO.json
# total companies uploaded: 178
# total tries: 201
# Successful CIK extraction for BIRD
# Successfully converted to json bytes
# Data for BIRD uploaded to S3: egdar_data/raw/2024-06-02/BIRD.json
# total companies uploaded: 179
# total tries: 202
# Successful CIK extraction for AISP
# Successfully converted to json bytes
# Data for AISP uploaded to S3: egdar_data/raw/2024-06-02/AISP.json
# total companies uploaded: 180
# total tries: 203
# Successful CIK extraction for BWEN
# Successfully converted to json bytes
# Data for BWEN uploaded to S3: egdar_data/raw/2024-06-02/BWEN.json
# total companies uploaded: 181
# total tries: 204
# Successful CIK extraction for TPZ
# HTTP error for TPZ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001408201.json
# total tries: 205
# Successful CIK extraction for SHLT
# Successfully converted to json bytes
# Data for SHLT uploaded to S3: egdar_data/raw/2024-06-02/SHLT.json
# total companies uploaded: 182
# total tries: 206
# Successful CIK extraction for ELDN
# Successfully converted to json bytes
# Data for ELDN uploaded to S3: egdar_data/raw/2024-06-02/ELDN.json
# total companies uploaded: 183
# total tries: 207
# Successful CIK extraction for MKFG
# Successfully converted to json bytes
# Data for MKFG uploaded to S3: egdar_data/raw/2024-06-02/MKFG.json
# total companies uploaded: 184
# total tries: 208
# Successful CIK extraction for FEIM
# Successfully converted to json bytes
# Data for FEIM uploaded to S3: egdar_data/raw/2024-06-02/FEIM.json
# total companies uploaded: 185
# total tries: 209
# Successful CIK extraction for IROH
# Successfully converted to json bytes
# Data for IROH uploaded to S3: egdar_data/raw/2024-06-02/IROH.json
# total companies uploaded: 186
# total tries: 210
# Successful CIK extraction for CITE
# Successfully converted to json bytes
# Data for CITE uploaded to S3: egdar_data/raw/2024-06-02/CITE.json
# total companies uploaded: 187
# total tries: 211
# Successful CIK extraction for GLST
# Successfully converted to json bytes
# Data for GLST uploaded to S3: egdar_data/raw/2024-06-02/GLST.json
# total companies uploaded: 188
# total tries: 212
# Successful CIK extraction for MHH
# Successfully converted to json bytes
# Data for MHH uploaded to S3: egdar_data/raw/2024-06-02/MHH.json
# total companies uploaded: 189
# total tries: 213
# Successful CIK extraction for GNT
# HTTP error for GNT: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001438893.json
# total tries: 214
# Successful CIK extraction for EUDA
# Successfully converted to json bytes
# Data for EUDA uploaded to S3: egdar_data/raw/2024-06-02/EUDA.json
# total companies uploaded: 190
# total tries: 215
# Successful CIK extraction for KRNL
# Successfully converted to json bytes
# Data for KRNL uploaded to S3: egdar_data/raw/2024-06-02/KRNL.json
# total companies uploaded: 191
# total tries: 216
# Successful CIK extraction for SRL
# Successfully converted to json bytes
# Data for SRL uploaded to S3: egdar_data/raw/2024-06-02/SRL.json
# total companies uploaded: 192
# total tries: 217
# Successful CIK extraction for RLMD
# Successfully converted to json bytes
# Data for RLMD uploaded to S3: egdar_data/raw/2024-06-02/RLMD.json
# total companies uploaded: 193
# total tries: 218
# Successful CIK extraction for ONYX
# Successfully converted to json bytes
# Data for ONYX uploaded to S3: egdar_data/raw/2024-06-02/ONYX.json
# total companies uploaded: 194
# total tries: 219
# Successful CIK extraction for FFNTF
# Successfully converted to json bytes
# Data for FFNTF uploaded to S3: egdar_data/raw/2024-06-02/FFNTF.json
# total companies uploaded: 195
# total tries: 220
# Successful CIK extraction for TMTC
# Successfully converted to json bytes
# Data for TMTC uploaded to S3: egdar_data/raw/2024-06-02/TMTC.json
# total companies uploaded: 196
# total tries: 221
# Successful CIK extraction for TTOO
# Successfully converted to json bytes
# Data for TTOO uploaded to S3: egdar_data/raw/2024-06-02/TTOO.json
# total companies uploaded: 197
# total tries: 222
# Successful CIK extraction for BUUZ
# Successfully converted to json bytes
# Data for BUUZ uploaded to S3: egdar_data/raw/2024-06-02/BUUZ.json
# total companies uploaded: 198
# total tries: 223
# Successful CIK extraction for RBKB
# Successfully converted to json bytes
# Data for RBKB uploaded to S3: egdar_data/raw/2024-06-02/RBKB.json
# total companies uploaded: 199
# total tries: 224
# Successful CIK extraction for CMTV
# Successfully converted to json bytes
# Data for CMTV uploaded to S3: egdar_data/raw/2024-06-02/CMTV.json
# total companies uploaded: 200
# total tries: 225
# Successful CIK extraction for SWVL
# Successfully converted to json bytes
# Data for SWVL uploaded to S3: egdar_data/raw/2024-06-02/SWVL.json
# total companies uploaded: 201
# total tries: 226
# Successful CIK extraction for FSRN
# Successfully converted to json bytes
# Data for FSRN uploaded to S3: egdar_data/raw/2024-06-02/FSRN.json
# total companies uploaded: 202
# total tries: 227
# Successful CIK extraction for WSTRF
# Successfully converted to json bytes
# Data for WSTRF uploaded to S3: egdar_data/raw/2024-06-02/WSTRF.json
# total companies uploaded: 203
# total tries: 228
# Successful CIK extraction for NANX
# Successfully converted to json bytes
# Data for NANX uploaded to S3: egdar_data/raw/2024-06-02/NANX.json
# total companies uploaded: 204
# total tries: 229
# Successful CIK extraction for ORMP
# Successfully converted to json bytes
# Data for ORMP uploaded to S3: egdar_data/raw/2024-06-02/ORMP.json
# total companies uploaded: 205
# total tries: 230
# Successful CIK extraction for ALLT
# Successfully converted to json bytes
# Data for ALLT uploaded to S3: egdar_data/raw/2024-06-02/ALLT.json
# total companies uploaded: 206
# total tries: 231
# Successful CIK extraction for PROV
# Successfully converted to json bytes
# Data for PROV uploaded to S3: egdar_data/raw/2024-06-02/PROV.json
# total companies uploaded: 207
# total tries: 232
# Successful CIK extraction for GAQ
# Successfully converted to json bytes
# Data for GAQ uploaded to S3: egdar_data/raw/2024-06-02/GAQ.json
# total companies uploaded: 208
# total tries: 233
# Successful CIK extraction for RSSS
# Successfully converted to json bytes
# Data for RSSS uploaded to S3: egdar_data/raw/2024-06-02/RSSS.json
# total companies uploaded: 209
# total tries: 234
# Successful CIK extraction for RTC
# Successfully converted to json bytes
# Data for RTC uploaded to S3: egdar_data/raw/2024-06-02/RTC.json
# total companies uploaded: 210
# total tries: 235
# Successful CIK extraction for DRTTF
# Successfully converted to json bytes
# Data for DRTTF uploaded to S3: egdar_data/raw/2024-06-02/DRTTF.json
# total companies uploaded: 211
# total tries: 236
# Successful CIK extraction for PETS
# Successfully converted to json bytes
# Data for PETS uploaded to S3: egdar_data/raw/2024-06-02/PETS.json
# total companies uploaded: 212
# total tries: 237
# Successful CIK extraction for CNGL
# Successfully converted to json bytes
# Data for CNGL uploaded to S3: egdar_data/raw/2024-06-02/CNGL.json
# total companies uploaded: 213
# total tries: 238
# Successful CIK extraction for NB
# Successfully converted to json bytes
# Data for NB uploaded to S3: egdar_data/raw/2024-06-02/NB.json
# total companies uploaded: 214
# total tries: 239
# Successful CIK extraction for OCFT
# Successfully converted to json bytes
# Data for OCFT uploaded to S3: egdar_data/raw/2024-06-02/OCFT.json
# total companies uploaded: 215
# total tries: 240
# Successful CIK extraction for IMAQ
# Successfully converted to json bytes
# Data for IMAQ uploaded to S3: egdar_data/raw/2024-06-02/IMAQ.json
# total companies uploaded: 216
# total tries: 241
# Successful CIK extraction for SRBK
# Successfully converted to json bytes
# Data for SRBK uploaded to S3: egdar_data/raw/2024-06-02/SRBK.json
# total companies uploaded: 217
# total tries: 242
# Successful CIK extraction for QNBC
# Successfully converted to json bytes
# Data for QNBC uploaded to S3: egdar_data/raw/2024-06-02/QNBC.json
# total companies uploaded: 218
# total tries: 243
# Successful CIK extraction for DNMR
# Successfully converted to json bytes
# Data for DNMR uploaded to S3: egdar_data/raw/2024-06-02/DNMR.json
# total companies uploaded: 219
# total tries: 244
# Successful CIK extraction for ENBP
# Successfully converted to json bytes
# Data for ENBP uploaded to S3: egdar_data/raw/2024-06-02/ENBP.json
# total companies uploaded: 220
# total tries: 245
# Successful CIK extraction for NEOV
# Successfully converted to json bytes
# Data for NEOV uploaded to S3: egdar_data/raw/2024-06-02/NEOV.json
# total companies uploaded: 221
# total tries: 246
# Successful CIK extraction for ARYD
# Successfully converted to json bytes
# Data for ARYD uploaded to S3: egdar_data/raw/2024-06-02/ARYD.json
# total companies uploaded: 222
# total tries: 247
# Successful CIK extraction for VOC
# HTTP error for VOC: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001505413.json
# total tries: 248
# Successful CIK extraction for HSPO
# Successfully converted to json bytes
# Data for HSPO uploaded to S3: egdar_data/raw/2024-06-02/HSPO.json
# total companies uploaded: 223
# total tries: 249
# Successful CIK extraction for KUKE
# Successfully converted to json bytes
# Data for KUKE uploaded to S3: egdar_data/raw/2024-06-02/KUKE.json
# total companies uploaded: 224
# total tries: 250
# Successful CIK extraction for GRTS
# Successfully converted to json bytes
# Data for GRTS uploaded to S3: egdar_data/raw/2024-06-02/GRTS.json
# total companies uploaded: 225
# total tries: 251
# Successful CIK extraction for PGP
# HTTP error for PGP: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001318025.json
# total tries: 252
# Successful CIK extraction for IFRX
# Successfully converted to json bytes
# Data for IFRX uploaded to S3: egdar_data/raw/2024-06-02/IFRX.json
# total companies uploaded: 226
# total tries: 253
# Successful CIK extraction for UONE
# Successfully converted to json bytes
# Data for UONE uploaded to S3: egdar_data/raw/2024-06-02/UONE.json
# total companies uploaded: 227
# total tries: 254
# Successful CIK extraction for GLU
# HTTP error for GLU: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001282957.json
# total tries: 255
# Successful CIK extraction for GAMC
# Successfully converted to json bytes
# Data for GAMC uploaded to S3: egdar_data/raw/2024-06-02/GAMC.json
# total companies uploaded: 228
# total tries: 256
# Successful CIK extraction for RENT
# Successfully converted to json bytes
# Data for RENT uploaded to S3: egdar_data/raw/2024-06-02/RENT.json
# total companies uploaded: 229
# total tries: 257
# Successful CIK extraction for ALVR
# Successfully converted to json bytes
# Data for ALVR uploaded to S3: egdar_data/raw/2024-06-02/ALVR.json
# total companies uploaded: 230
# total tries: 258
# Successful CIK extraction for BHAC
# Successfully converted to json bytes
# Data for BHAC uploaded to S3: egdar_data/raw/2024-06-02/BHAC.json
# total companies uploaded: 231
# total tries: 259
# Successful CIK extraction for TORO
# Successfully converted to json bytes
# Data for TORO uploaded to S3: egdar_data/raw/2024-06-02/TORO.json
# total companies uploaded: 232
# total tries: 260
# Successful CIK extraction for CRT
# HTTP error for CRT: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000881787.json
# total tries: 261
# Successful CIK extraction for PSBQ
# Successfully converted to json bytes
# Data for PSBQ uploaded to S3: egdar_data/raw/2024-06-02/PSBQ.json
# total companies uploaded: 233
# total tries: 262
# Successful CIK extraction for HGBL
# Successfully converted to json bytes
# Data for HGBL uploaded to S3: egdar_data/raw/2024-06-02/HGBL.json
# total companies uploaded: 234
# total tries: 263
# Successful CIK extraction for DOMA
# Successfully converted to json bytes
# ...
# total tries: 485
# Successful CIK extraction for GLLI
# Successfully converted to json bytes
# Data for GLLI uploaded to S3: egdar_data/raw/2024-06-02/GLLI.json
# total companies uploaded: 442
# total tries: 486
# Successful CIK extraction for BHM
# Successfully converted to json bytes
# Data for BHM uploaded to S3: egdar_data/raw/2024-06-02/BHM.json
# total companies uploaded: 443
# total tries: 487
# Successful CIK extraction for BTAI
# Successfully converted to json bytes
# Data for BTAI uploaded to S3: egdar_data/raw/2024-06-02/BTAI.json
# total companies uploaded: 444
# total tries: 488
# Successful CIK extraction for HAIA
# Successfully converted to json bytes
# Data for HAIA uploaded to S3: egdar_data/raw/2024-06-02/HAIA.json
# total companies uploaded: 445
# total tries: 489
# Successful CIK extraction for CKPT
# Successfully converted to json bytes
# Data for CKPT uploaded to S3: egdar_data/raw/2024-06-02/CKPT.json
# total companies uploaded: 446
# total tries: 490
# Successful CIK extraction for TTP
# HTTP error for TTP: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001526329.json
# total tries: 491
# Successful CIK extraction for MNOV
# Successfully converted to json bytes
# Data for MNOV uploaded to S3: egdar_data/raw/2024-06-02/MNOV.json
# total companies uploaded: 447
# total tries: 492
# Successful CIK extraction for INTS
# Successfully converted to json bytes
# Data for INTS uploaded to S3: egdar_data/raw/2024-06-02/INTS.json
# total companies uploaded: 448
# total tries: 493
# Successful CIK extraction for MOBX
# Successfully converted to json bytes
# Data for MOBX uploaded to S3: egdar_data/raw/2024-06-02/MOBX.json
# total companies uploaded: 449
# total tries: 494
# Successful CIK extraction for PGZ
# HTTP error for PGZ: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001557523.json
# total tries: 495
# Successful CIK extraction for VHAQ
# Successfully converted to json bytes
# Data for VHAQ uploaded to S3: egdar_data/raw/2024-06-02/VHAQ.json
# total companies uploaded: 450
# total tries: 496
# Successful CIK extraction for SGRP
# Successfully converted to json bytes
# Data for SGRP uploaded to S3: egdar_data/raw/2024-06-02/SGRP.json
# total companies uploaded: 451
# total tries: 497
# Successful CIK extraction for AIXI
# Successfully converted to json bytes
# Data for AIXI uploaded to S3: egdar_data/raw/2024-06-02/AIXI.json
# total companies uploaded: 452
# total tries: 498
# Successful CIK extraction for CPTP
# Successfully converted to json bytes
# Data for CPTP uploaded to S3: egdar_data/raw/2024-06-02/CPTP.json
# total companies uploaded: 453
# total tries: 499
# Successful CIK extraction for IHTA
# Successfully converted to json bytes
# Data for IHTA uploaded to S3: egdar_data/raw/2024-06-02/IHTA.json
# total companies uploaded: 454
# total tries: 500
# Successful CIK extraction for TGLO
# Successfully converted to json bytes
# Data for TGLO uploaded to S3: egdar_data/raw/2024-06-02/TGLO.json
# total companies uploaded: 455
# total tries: 501
# Successful CIK extraction for AVRO
# Successfully converted to json bytes
# Data for AVRO uploaded to S3: egdar_data/raw/2024-06-02/AVRO.json
# total companies uploaded: 456
# total tries: 502
# Successful CIK extraction for IOR
# Successfully converted to json bytes
# Data for IOR uploaded to S3: egdar_data/raw/2024-06-02/IOR.json
# total companies uploaded: 457
# total tries: 503
# Successful CIK extraction for VBFC
# Successfully converted to json bytes
# Data for VBFC uploaded to S3: egdar_data/raw/2024-06-02/VBFC.json
# total companies uploaded: 458
# total tries: 504
# Successful CIK extraction for PDEX
# Successfully converted to json bytes
# Data for PDEX uploaded to S3: egdar_data/raw/2024-06-02/PDEX.json
# total companies uploaded: 459
# total tries: 505
# Successful CIK extraction for WRAP
# Successfully converted to json bytes
# Data for WRAP uploaded to S3: egdar_data/raw/2024-06-02/WRAP.json
# total companies uploaded: 460
# total tries: 506
# Successful CIK extraction for GGROU
# Successfully converted to json bytes
# Data for GGROU uploaded to S3: egdar_data/raw/2024-06-02/GGROU.json
# total companies uploaded: 461
# total tries: 507
# Successful CIK extraction for AUBN
# Successfully converted to json bytes
# Data for AUBN uploaded to S3: egdar_data/raw/2024-06-02/AUBN.json
# total companies uploaded: 462
# total tries: 508
# Successful CIK extraction for RDGL
# Successfully converted to json bytes
# Data for RDGL uploaded to S3: egdar_data/raw/2024-06-02/RDGL.json
# total companies uploaded: 463
# total tries: 509
# Successful CIK extraction for DMA
# Successfully converted to json bytes
# Data for DMA uploaded to S3: egdar_data/raw/2024-06-02/DMA.json
# total companies uploaded: 464
# total tries: 510
# Successful CIK extraction for WFCF
# Successfully converted to json bytes
# Data for WFCF uploaded to S3: egdar_data/raw/2024-06-02/WFCF.json
# total companies uploaded: 465
# total tries: 511
# Successful CIK extraction for GVXXF
# HTTP error for GVXXF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001490596.json
# total tries: 512
# Successful CIK extraction for RAASY
# Successfully converted to json bytes
# Data for RAASY uploaded to S3: egdar_data/raw/2024-06-02/RAASY.json
# total companies uploaded: 466
# total tries: 513
# Successful CIK extraction for AFAR
# Successfully converted to json bytes
# Data for AFAR uploaded to S3: egdar_data/raw/2024-06-02/AFAR.json
# total companies uploaded: 467
# total tries: 514
# Successful CIK extraction for QUBT
# Successfully converted to json bytes
# Data for QUBT uploaded to S3: egdar_data/raw/2024-06-02/QUBT.json
# total companies uploaded: 468
# total tries: 515
# Successful CIK extraction for LDTC
# Successfully converted to json bytes
# Data for LDTC uploaded to S3: egdar_data/raw/2024-06-02/LDTC.json
# total companies uploaded: 469
# total tries: 516
# Successful CIK extraction for SCOR
# Successfully converted to json bytes
# Data for SCOR uploaded to S3: egdar_data/raw/2024-06-02/SCOR.json
# total companies uploaded: 470
# total tries: 517
# Successful CIK extraction for CLOE
# Successfully converted to json bytes
# Data for CLOE uploaded to S3: egdar_data/raw/2024-06-02/CLOE.json
# total companies uploaded: 471
# total tries: 518
# Successful CIK extraction for RGC
# Successfully converted to json bytes
# Data for RGC uploaded to S3: egdar_data/raw/2024-06-02/RGC.json
# total companies uploaded: 472
# total tries: 519
# Successful CIK extraction for NVNO
# Successfully converted to json bytes
# Data for NVNO uploaded to S3: egdar_data/raw/2024-06-02/NVNO.json
# total companies uploaded: 473
# total tries: 520
# Successful CIK extraction for PLBY
# Successfully converted to json bytes
# Data for PLBY uploaded to S3: egdar_data/raw/2024-06-02/PLBY.json
# total companies uploaded: 474
# total tries: 521
# Successful CIK extraction for FAM
# HTTP error for FAM: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001302624.json
# total tries: 522
# Successful CIK extraction for FTII
# Successfully converted to json bytes
# Data for FTII uploaded to S3: egdar_data/raw/2024-06-02/FTII.json
# total companies uploaded: 475
# total tries: 523
# Successful CIK extraction for CEE
# Successfully converted to json bytes
# Data for CEE uploaded to S3: egdar_data/raw/2024-06-02/CEE.json
# total companies uploaded: 476
# total tries: 524
# Successful CIK extraction for RFAC
# Successfully converted to json bytes
# Data for RFAC uploaded to S3: egdar_data/raw/2024-06-02/RFAC.json
# total companies uploaded: 477
# total tries: 525
# Successful CIK extraction for CRIS
# Successfully converted to json bytes
# Data for CRIS uploaded to S3: egdar_data/raw/2024-06-02/CRIS.json
# total companies uploaded: 478
# total tries: 526
# Successful CIK extraction for BHAT
# Successfully converted to json bytes
# Data for BHAT uploaded to S3: egdar_data/raw/2024-06-02/BHAT.json
# total companies uploaded: 479
# total tries: 527
# Successful CIK extraction for BEDU
# Successfully converted to json bytes
# Data for BEDU uploaded to S3: egdar_data/raw/2024-06-02/BEDU.json
# total companies uploaded: 480
# total tries: 528
# Successful CIK extraction for ASXC
# Successfully converted to json bytes
# Data for ASXC uploaded to S3: egdar_data/raw/2024-06-02/ASXC.json
# total companies uploaded: 481
# total tries: 529
# Successful CIK extraction for BWAQ
# Successfully converted to json bytes
# Data for BWAQ uploaded to S3: egdar_data/raw/2024-06-02/BWAQ.json
# total companies uploaded: 482
# total tries: 530
# Successful CIK extraction for LTRPA
# Successfully converted to json bytes
# Data for LTRPA uploaded to S3: egdar_data/raw/2024-06-02/LTRPA.json
# total companies uploaded: 483
# total tries: 531
# Successful CIK extraction for SYT
# Successfully converted to json bytes
# Data for SYT uploaded to S3: egdar_data/raw/2024-06-02/SYT.json
# total companies uploaded: 484
# total tries: 532
# Successful CIK extraction for LTRN
# Successfully converted to json bytes
# Data for LTRN uploaded to S3: egdar_data/raw/2024-06-02/LTRN.json
# total companies uploaded: 485
# total tries: 533
# Successful CIK extraction for SFRX
# Successfully converted to json bytes
# Data for SFRX uploaded to S3: egdar_data/raw/2024-06-02/SFRX.json
# total companies uploaded: 486
# total tries: 534
# Successful CIK extraction for MGRM
# Successfully converted to json bytes
# Data for MGRM uploaded to S3: egdar_data/raw/2024-06-02/MGRM.json
# total companies uploaded: 487
# total tries: 535
# Successful CIK extraction for NBST
# Successfully converted to json bytes
# Data for NBST uploaded to S3: egdar_data/raw/2024-06-02/NBST.json
# total companies uploaded: 488
# total tries: 536
# Successful CIK extraction for SPRU
# Successfully converted to json bytes
# Data for SPRU uploaded to S3: egdar_data/raw/2024-06-02/SPRU.json
# total companies uploaded: 489
# total tries: 537
# Successful CIK extraction for FGNV
# Successfully converted to json bytes
# Data for FGNV uploaded to S3: egdar_data/raw/2024-06-02/FGNV.json
# total companies uploaded: 490
# total tries: 538
# Successful CIK extraction for AIRRF
# HTTP error for AIRRF: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001476573.json
# total tries: 539
# Successful CIK extraction for HYPR
# Successfully converted to json bytes
# Data for HYPR uploaded to S3: egdar_data/raw/2024-06-02/HYPR.json
# total companies uploaded: 491
# total tries: 540
# Successful CIK extraction for AFMD
# Successfully converted to json bytes
# Data for AFMD uploaded to S3: egdar_data/raw/2024-06-02/AFMD.json
# total companies uploaded: 492
# total tries: 541
# Successful CIK extraction for LVTX
# Successfully converted to json bytes
# Data for LVTX uploaded to S3: egdar_data/raw/2024-06-02/LVTX.json
# total companies uploaded: 493
# total tries: 542
# Successful CIK extraction for UCL
# Successfully converted to json bytes
# Data for UCL uploaded to S3: egdar_data/raw/2024-06-02/UCL.json
# total companies uploaded: 494
# total tries: 543
# Successful CIK extraction for VNRX
# Successfully converted to json bytes
# Data for VNRX uploaded to S3: egdar_data/raw/2024-06-02/VNRX.json
# total companies uploaded: 495
# total tries: 544
# Successful CIK extraction for ENZ
# Successfully converted to json bytes
# Data for ENZ uploaded to S3: egdar_data/raw/2024-06-02/ENZ.json
# total companies uploaded: 496
# total tries: 545
# Successful CIK extraction for STCB
# Successfully converted to json bytes
# Data for STCB uploaded to S3: egdar_data/raw/2024-06-02/STCB.json
# total companies uploaded: 497
# total tries: 546
# Successful CIK extraction for RTGN
# Successfully converted to json bytes
# Data for RTGN uploaded to S3: egdar_data/raw/2024-06-02/RTGN.json
# total companies uploaded: 498
# total tries: 547
# Successful CIK extraction for IGTA
# Successfully converted to json bytes
# Data for IGTA uploaded to S3: egdar_data/raw/2024-06-02/IGTA.json
# total companies uploaded: 499
# total tries: 548
# Successful CIK extraction for TOPS
# Successfully converted to json bytes
# Data for TOPS uploaded to S3: egdar_data/raw/2024-06-02/TOPS.json
# total companies uploaded: 500
# total tries: 549
# Successful CIK extraction for DHAI
# Successfully converted to json bytes
# Data for DHAI uploaded to S3: egdar_data/raw/2024-06-02/DHAI.json
# total companies uploaded: 501
# total tries: 550
# Successful CIK extraction for FARM
# Successfully converted to json bytes
# Data for FARM uploaded to S3: egdar_data/raw/2024-06-02/FARM.json
# total companies uploaded: 502
# total tries: 551
# Successful CIK extraction for FLFV
# Successfully converted to json bytes
# Data for FLFV uploaded to S3: egdar_data/raw/2024-06-02/FLFV.json
# total companies uploaded: 503
# total tries: 552
# Successful CIK extraction for NMS
# HTTP error for NMS: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001607997.json
# total tries: 553
# Successful CIK extraction for NTZ
# Successfully converted to json bytes
# Data for NTZ uploaded to S3: egdar_data/raw/2024-06-02/NTZ.json
# total companies uploaded: 504
# total tries: 554
# Successful CIK extraction for NRT
# HTTP error for NRT: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0000072633.json
# total tries: 555
# Successful CIK extraction for STIM
# Successfully converted to json bytes
# Data for STIM uploaded to S3: egdar_data/raw/2024-06-02/STIM.json
# total companies uploaded: 505
# total tries: 556
# Successful CIK extraction for VGZ
# Successfully converted to json bytes
# Data for VGZ uploaded to S3: egdar_data/raw/2024-06-02/VGZ.json
# total companies uploaded: 506
# total tries: 557
# Successful CIK extraction for CSBR
# Successfully converted to json bytes
# Data for CSBR uploaded to S3: egdar_data/raw/2024-06-02/CSBR.json
# total companies uploaded: 507
# total tries: 558
# Successful CIK extraction for RSKIA
# Successfully converted to json bytes
# Data for RSKIA uploaded to S3: egdar_data/raw/2024-06-02/RSKIA.json
# total companies uploaded: 508
# total tries: 559
# Successful CIK extraction for MFD
# HTTP error for MFD: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001276469.json
# total tries: 560
# Successful CIK extraction for DWSN
# Successfully converted to json bytes
# Data for DWSN uploaded to S3: egdar_data/raw/2024-06-02/DWSN.json
# total companies uploaded: 509
# total tries: 561
# Successful CIK extraction for NWPP
# Successfully converted to json bytes
# Data for NWPP uploaded to S3: egdar_data/raw/2024-06-02/NWPP.json
# total companies uploaded: 510
# total tries: 562
# Successful CIK extraction for SLBK
# Successfully converted to json bytes
# Data for SLBK uploaded to S3: egdar_data/raw/2024-06-02/SLBK.json
# total companies uploaded: 511
# total tries: 563
# Successful CIK extraction for ETST
# Successfully converted to json bytes
# Data for ETST uploaded to S3: egdar_data/raw/2024-06-02/ETST.json
# total companies uploaded: 512
# total tries: 564
# Successful CIK extraction for CHMX
# Successfully converted to json bytes
# Data for CHMX uploaded to S3: egdar_data/raw/2024-06-02/CHMX.json
# total companies uploaded: 513
# total tries: 565
# Successful CIK extraction for RLYB
# Successfully converted to json bytes
# Data for RLYB uploaded to S3: egdar_data/raw/2024-06-02/RLYB.json
# total companies uploaded: 514
# total tries: 566
# Successful CIK extraction for CHCI
# Successfully converted to json bytes
# Data for CHCI uploaded to S3: egdar_data/raw/2024-06-02/CHCI.json
# total companies uploaded: 515
# total tries: 567
# Successful CIK extraction for GAN
# Successfully converted to json bytes
# Data for GAN uploaded to S3: egdar_data/raw/2024-06-02/GAN.json
# total companies uploaded: 516
# total tries: 568
# Successful CIK extraction for FLCX
# Successfully converted to json bytes
# Data for FLCX uploaded to S3: egdar_data/raw/2024-06-02/FLCX.json
# total companies uploaded: 517
# total tries: 569
# Successful CIK extraction for MCHX
# Successfully converted to json bytes
# Data for MCHX uploaded to S3: egdar_data/raw/2024-06-02/MCHX.json
# total companies uploaded: 518
# total tries: 570
# Successful CIK extraction for ANTX
# Successfully converted to json bytes
# Data for ANTX uploaded to S3: egdar_data/raw/2024-06-02/ANTX.json
# total companies uploaded: 519
# total tries: 571
# Successful CIK extraction for RAY
# HTTP error for RAY: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyfacts/CIK0001948443.json
# total tries: 572
# total companies uploaded: 519
